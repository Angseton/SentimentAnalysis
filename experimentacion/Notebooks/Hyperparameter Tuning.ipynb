# %%
import pandas as pd
import numpy as np
import subprocess
from itertools import chain, product

# %%
PARAMS_TO_FLAGS = {
    'dataset': '-i',
    'output_file': '-o',
    'mode': '-m',
    'k': '-k',
    'alpha': '-a',
    'threshold_frecuency_low': '-f_low',
    'threshold_frecuency_high': '-f_high',
}

def build_grid(ranges):
    """Build grid based on ranges."""
    def as_list(elmt):
        """Convert elmt to list if elmt is not list."""
        if isinstance(elmt, list):
            return elmt
        else:
            return [elmt]

    grid = product(*(as_list(i) for i in ranges.values()))
    for p in grid:
        yield (dict(zip(ranges.keys(), p)))

# %%
grid_ranges = {
    'dataset': ['../data/train_test_sample_1000.csv'],
    'output_file': ['../../datos/out.csv'], # Todavia no hace nada
    'mode': [0, 1],
    'k': [1, 2, 3, 4, 5, 10, 20, 30, 50],
    'alpha': [0, 1, 5, 10, 15, 20, 25, 30, 50],
    'threshold_frecuency_low': [0.01],
    'threshold_frecuency_high': [0.99],
}

# Un generator(iterador) de los puntos de la grilla
grid = list(build_grid(ranges=grid_ranges))
print(grid[0])
print(grid[1])
print(grid[2])
# Out:
# {'dataset': '../data/train_test_sample_1000.csv', 'output_file': '../../datos/out.csv', 'mode': 0, 'k': 1, 'alpha': 0, 'threshold_frecuency_low': 0.01, 'threshold_frecuency_high': 0.99}
# {'dataset': '../data/train_test_sample_1000.csv', 'output_file': '../../datos/out.csv', 'mode': 0, 'k': 1, 'alpha': 1, 'threshold_frecuency_low': 0.01, 'threshold_frecuency_high': 0.99}
# {'dataset': '../data/train_test_sample_1000.csv', 'output_file': '../../datos/out.csv', 'mode': 0, 'k': 1, 'alpha': 5, 'threshold_frecuency_low': 0.01, 'threshold_frecuency_high': 0.99}

# %%
def parse_results(output, niters):
    N, time, eigen_val, *eigen_vec = list(map(float, output.decode().split('\n')[:-1]))
    return {
        'N': N,
        'time': time,
        'niters': niters,
        'eigen_val': eigen_val,
        'eigen_vec': np.array(eigen_vec),
    }


def output_to_dict(output):
    # Parsear la salida a un diccionario
    lines = output.decode().split('\n')
    d = dict(tuple(l.split(': ')) for l in lines if ': ' in l)
    for k, v in d.items():
        if k != 'Dataset File':
            d[k] = float(v)
    return d

def run(exc_path, params):
    args = tuple(chain(*((PARAMS_TO_FLAGS[p], str(v)) for p, v in params.items())))
    args = [exc_path, *args]
    output = subprocess.check_output(args)
    return output_to_dict(output)

# %%
EXEC_PATH = '../executables/tp2'
param_set = {
    'dataset': '../data/train_test_sample_1000.csv', 
    'output_file': '../../datos/out.csv', 
    'mode': 0, 
    'k': 1, 
    'alpha': 0, 
    'threshold_frecuency_low': 0.01, 
    'threshold_frecuency_high': 0.99
}
out = run(EXEC_PATH, param_set)
out
# Out:
# {'Dataset File': '../data/train_test_sample_1000.csv',
#  'mode': 0.0,
#  'k': 1.0,
#  'alpha': 0.0,
#  'threshold_frecuency_low': 0.01,
#  'threshold_frecuency_high': 0.99,
#  'tp': 557.0,
#  'fp': 400.0,
#  'tn': 837.0,
#  'fn': 706.0,
#  'Accuracy': 0.5576,
#  'Precision': 0.441013,
#  'Recall': 0.582027,
#  'F1': 0.501802,
#  'Time': 4.43996}

# %%
# Correrlo para una grilla chica para ver que pasa con los thresholds
grid_ranges = {
    'dataset': ['../data/train_test_sample_1000.csv'],
    'output_file': ['../../datos/out.csv'], # Todavia no hace nada
    'mode': [0],
    'k': [5],
    'alpha': [0],
    'threshold_frecuency_low': [0.01, 0.05, 0.1, 0.15, 0.2, 0.25],
    'threshold_frecuency_high': [0.8, 0.85, 0.9, 0.95, 0.99],
}
results = []
grid = list(build_grid(grid_ranges))
for i, point in enumerate(grid):
    print('\r', f'Running for point {i+1}/{len(grid)}', end='         ')
    out = run(EXEC_PATH, point)
    results.append(out)
results_df = pd.DataFrame(results)
# Out:
#  Running for point 30/30

# %%
results_df.head()
# Out:
#    Accuracy                        Dataset File        F1  Precision  \
# 0    0.5740  ../data/train_test_sample_1000.csv  0.492616   0.409343
# 1    0.5704  ../data/train_test_sample_1000.csv  0.487595   0.404592
# 2    0.5692  ../data/train_test_sample_1000.csv  0.488361   0.406968
# 3    0.5700  ../data/train_test_sample_1000.csv  0.477902   0.389549
# 4    0.5816  ../data/train_test_sample_1000.csv  0.503795   0.420428
#
#      Recall     Time  alpha     fn     fp    k  mode  \
# 0  0.618421  4.41691    0.0  746.0  319.0  5.0   0.0
# 1  0.613445  4.42123    0.0  752.0  322.0  5.0   0.0
# 2  0.610451  4.41246    0.0  749.0  328.0  5.0   0.0
# 3  0.618090  4.38617    0.0  771.0  304.0  5.0   0.0
# 4  0.628402  4.37539    0.0  732.0  314.0  5.0   0.0
#
#    threshold_frecuency_high  threshold_frecuency_low     tn     tp
# 0                      0.80                     0.01  918.0  517.0
# 1                      0.85                     0.01  915.0  511.0
# 2                      0.90                     0.01  909.0  514.0
# 3                      0.95                     0.01  933.0  492.0
# 4                      0.99                     0.01  923.0  531.0

# %%
# results_df.sort_values('Accuracy')

# %%
# pareceria ser que los valores de los thresholds en 0.2 y 0.95 son los mejores.
# Igual es un conjunto de datos bastante chico habria que probar con mas datos

# %%
import sys
from multiprocessing import Pool

def run_grid_in_parallel(grid, n_proc=18):
    """Run a grid on n_proc workers"""
    done, results = 0, []
    
    def call_back(out):
        nonlocal done
        nonlocal results
        results.append(out)
        done += 1
        print('\r', f'Point {done}/{len(grid)} done', end='         ')
        sys.stdout.flush()

    with Pool(n_proc) as pool:
        for point in grid:
            pool.apply_async(run, args=(EXEC_PATH, point, ), callback=call_back)
        pool.close()
        pool.join()
    return pd.DataFrame(results)

grid_ranges = {
    'dataset': ['../data/train_test_sample_1000.csv'],
    'output_file': ['../../datos/out.csv'], # Todavia no hace nada
    'mode': [0],
    'k': [5],
    'alpha': [0],
    'threshold_frecuency_low': [0.01, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.4, 0.5],
    'threshold_frecuency_high': [0.7, 0.75, 0.8, 0.85, 0.9, 0.95, 0.99],
}
grid = list(build_grid(grid_ranges))
res = run_grid_in_parallel(grid)
# Out:
#  Point 63/63 done

# %%
res.sort_values('Accuracy', ascending=False).head()
# Out:
#     Accuracy                        Dataset File        F1  Precision  \
# 30    0.5872  ../data/train_test_sample_1000.csv  0.530055   0.460808
# 13    0.5856  ../data/train_test_sample_1000.csv  0.523020   0.449723
# 20    0.5844  ../data/train_test_sample_1000.csv  0.525354   0.455265
# 8     0.5844  ../data/train_test_sample_1000.csv  0.521419   0.448139
# 59    0.5816  ../data/train_test_sample_1000.csv  0.503795   0.420428
#
#       Recall      Time  alpha     fn     fp    k  mode  \
# 30  0.623794  0.509370    0.0  681.0  351.0  5.0   0.0
# 13  0.624862  0.844421    0.0  695.0  341.0  5.0   0.0
# 20  0.620950  0.679705    0.0  688.0  351.0  5.0   0.0
# 8   0.623348  1.703990    0.0  697.0  342.0  5.0   0.0
# 59  0.628402  6.064110    0.0  732.0  314.0  5.0   0.0
#
#     threshold_frecuency_high  threshold_frecuency_low     tn     tp
# 30                      0.99                     0.20  886.0  582.0
# 13                      0.99                     0.10  896.0  568.0
# 20                      0.99                     0.15  886.0  575.0
# 8                       0.99                     0.05  895.0  566.0
# 59                      0.99                     0.01  923.0  531.0

# %%
def score_metrics(scores, metrics=['Accuracy', 'F1','Precision', 'Recall'], top=5):
    for metric in metrics:
        for t in range(top):
            scores.sort_values(metric, ascending=False).iloc[t]

# %%
import sys
from multiprocessing import Pool

def run_grid_in_parallel(grid, n_proc=18):
    """Run a grid on n_proc workers"""
    done, results = 0, []
    
    def call_back(out):
        nonlocal done
        nonlocal results
        results.append(out)
        done += 1
        print('\r', f'Point {done}/{len(grid)} done', end='         ')
        sys.stdout.flush()

    with Pool(n_proc) as pool:
        for point in grid:
            pool.apply_async(run, args=(EXEC_PATH, point, ), callback=call_back)
        pool.close()
        pool.join()
    return pd.DataFrame(results)

grid_ranges = {
    'dataset': ['../data/train_test_sample_1000.csv'],
    'output_file': ['../../datos/out.csv'], # Todavia no hace nada
    'mode': [1],
    'k': [1, 2, 3, 5, 7, 9, 10, 15, 20],
    'alpha': [25, 50, 75, 100, 150],
    'threshold_frecuency_low': [0.05],
    'threshold_frecuency_high': [0.99],
}
grid = list(build_grid(grid_ranges))
res_2 = run_grid_in_parallel(grid)
# Out:
#  Point 45/45 done

# %%
res_2.sort_values('Precision', ascending=False)
# Out:
#     Accuracy                        Dataset File        F1  Precision  \
# 11    0.5700  ../data/train_test_sample_1000.csv  0.539615   0.498812
# 0     0.5464  ../data/train_test_sample_1000.csv  0.524329   0.494854
# 7     0.5680  ../data/train_test_sample_1000.csv  0.534884   0.491686
# 15    0.5652  ../data/train_test_sample_1000.csv  0.530859   0.486936
# 4     0.5584  ../data/train_test_sample_1000.csv  0.526587   0.486144
# 8     0.5800  ../data/train_test_sample_1000.csv  0.535398   0.479018
# 3     0.5732  ../data/train_test_sample_1000.csv  0.530163   0.476643
# 10    0.5904  ../data/train_test_sample_1000.csv  0.537906   0.471892
# 12    0.5708  ../data/train_test_sample_1000.csv  0.524169   0.467933
# 1     0.5516  ../data/train_test_sample_1000.csv  0.513244   0.467933
# 2     0.5604  ../data/train_test_sample_1000.csv  0.516498   0.464766
# 28    0.5908  ../data/train_test_sample_1000.csv  0.532663   0.461599
# 17    0.5732  ../data/train_test_sample_1000.csv  0.522167   0.461599
# 29    0.6012  ../data/train_test_sample_1000.csv  0.538212   0.460016
# 21    0.5880  ../data/train_test_sample_1000.csv  0.530109   0.460016
# 26    0.5960  ../data/train_test_sample_1000.csv  0.533272   0.456849
# 25    0.5912  ../data/train_test_sample_1000.csv  0.529032   0.454473
# 23    0.5880  ../data/train_test_sample_1000.csv  0.526219   0.452890
# 31    0.5944  ../data/train_test_sample_1000.csv  0.529248   0.451306
# 20    0.5728  ../data/train_test_sample_1000.csv  0.515426   0.449723
# 18    0.5628  ../data/train_test_sample_1000.csv  0.509205   0.448931
# 5     0.5704  ../data/train_test_sample_1000.csv  0.512704   0.447348
# 34    0.5936  ../data/train_test_sample_1000.csv  0.525234   0.444972
# 40    0.5984  ../data/train_test_sample_1000.csv  0.524171   0.437846
# 30    0.5876  ../data/train_test_sample_1000.csv  0.516643   0.436263
# 37    0.6004  ../data/train_test_sample_1000.csv  0.524059   0.435471
# 24    0.5772  ../data/train_test_sample_1000.csv  0.506305   0.429137
# 19    0.5676  ../data/train_test_sample_1000.csv  0.499769   0.427553
# 42    0.5896  ../data/train_test_sample_1000.csv  0.511429   0.425178
# 36    0.5944  ../data/train_test_sample_1000.csv  0.512500   0.422011
# 38    0.5836  ../data/train_test_sample_1000.csv  0.471305   0.367379
# 44    0.5936  ../data/train_test_sample_1000.csv  0.473029   0.361045
# 41    0.5868  ../data/train_test_sample_1000.csv  0.465044   0.355503
# 43    0.5884  ../data/train_test_sample_1000.csv  0.464341   0.353127
# 39    0.5876  ../data/train_test_sample_1000.csv  0.462180   0.350752
# 33    0.5812  ../data/train_test_sample_1000.csv  0.450394   0.339667
# 32    0.5780  ../data/train_test_sample_1000.csv  0.445029   0.334917
# 22    0.5564  ../data/train_test_sample_1000.csv  0.432156   0.334125
# 27    0.5732  ../data/train_test_sample_1000.csv  0.440482   0.332542
# 35    0.5720  ../data/train_test_sample_1000.csv  0.436842   0.328583
# 14    0.5648  ../data/train_test_sample_1000.csv  0.390135   0.275534
# 13    0.5644  ../data/train_test_sample_1000.csv  0.383701   0.268409
# 9     0.5552  ../data/train_test_sample_1000.csv  0.375982   0.265241
# 6     0.5404  ../data/train_test_sample_1000.csv  0.355580   0.250990
# 16    0.5508  ../data/train_test_sample_1000.csv  0.357184   0.247031
#
#       Recall      Time  alpha     fn     fp     k  mode  \
# 11  0.587687   9.90495  100.0  633.0  442.0   1.0   1.0
# 0   0.557538   9.65571   25.0  638.0  496.0   1.0   1.0
# 7   0.586402   9.80549   75.0  642.0  438.0   1.0   1.0
# 15  0.583491  10.09740  150.0  648.0  439.0   1.0   1.0
# 4   0.574369   9.77640   50.0  649.0  455.0   1.0   1.0
# 8   0.606820   9.82377   75.0  658.0  392.0   3.0   1.0
# 3   0.597222   9.75154   50.0  661.0  406.0   3.0   1.0
# 10  0.625393   9.83525   75.0  667.0  357.0   5.0   1.0
# 12  0.595766   9.92552  100.0  672.0  401.0   3.0   1.0
# 1   0.568269   9.66071   25.0  672.0  449.0   3.0   1.0
# 2   0.581188   9.72076   25.0  676.0  423.0   5.0   1.0
# 28  0.629590  10.02940  150.0  680.0  343.0   5.0   1.0
# 17  0.601031  10.13490  150.0  680.0  387.0   3.0   1.0
# 29  0.648438   9.87326  100.0  682.0  315.0   9.0   1.0
# 21  0.625404   9.79692  100.0  682.0  348.0   5.0   1.0
# 26  0.640400   9.76895   75.0  686.0  324.0   9.0   1.0
# 25  0.632856   9.82547  100.0  689.0  333.0   7.0   1.0
# 23  0.627881   9.77268   75.0  691.0  339.0   7.0   1.0
# 31  0.639731  10.03410  150.0  693.0  321.0   7.0   1.0
# 20  0.603613   9.62126   25.0  695.0  373.0   9.0   1.0
# 18  0.588174   9.63581   25.0  696.0  397.0   7.0   1.0
# 5   0.600425   9.77089   50.0  698.0  376.0   5.0   1.0
# 34  0.640821  10.21100  150.0  701.0  315.0   9.0   1.0
# 40  0.652893   8.54425  100.0  710.0  294.0  15.0   1.0
# 30  0.633333   9.65964   25.0  712.0  319.0  15.0   1.0
# 37  0.657895   8.45950   75.0  713.0  286.0  15.0   1.0
# 24  0.617312   9.75338   50.0  721.0  336.0   9.0   1.0
# 19  0.601336   9.68899   50.0  723.0  358.0   7.0   1.0
# 42  0.641577   8.67783  150.0  726.0  300.0  15.0   1.0
# 36  0.652387   8.40444   50.0  730.0  284.0  15.0   1.0
# 38  0.657224   8.37491   25.0  799.0  242.0  20.0   1.0
# 44  0.685714   8.82309   75.0  807.0  209.0  20.0   1.0
# 41  0.672156   8.52118  100.0  814.0  219.0  20.0   1.0
# 43  0.677812   8.65228  150.0  817.0  212.0  20.0   1.0
# 39  0.677370   8.37494   50.0  820.0  211.0  20.0   1.0
# 33  0.668224  10.05690   75.0  834.0  213.0  10.0   1.0
# 32  0.663009   9.86826  100.0  840.0  215.0  10.0   1.0
# 22  0.611594   9.59865   25.0  841.0  268.0  10.0   1.0
# 27  0.652174   9.69432   50.0  843.0  224.0  10.0   1.0
# 35  0.651491  10.00290  150.0  848.0  222.0  10.0   1.0
# 14  0.667946  10.03660   75.0  915.0  173.0   2.0   1.0
# 13  0.672619   9.95007  100.0  924.0  165.0   2.0   1.0
# 9   0.645472   9.84459   50.0  928.0  184.0   2.0   1.0
# 6   0.609615   9.80267   25.0  946.0  203.0   2.0   1.0
# 16  0.644628  10.11470  150.0  951.0  172.0   2.0   1.0
#
#     threshold_frecuency_high  threshold_frecuency_low      tn     tp
# 11                      0.99                     0.05   795.0  630.0
# 0                       0.99                     0.05   741.0  625.0
# 7                       0.99                     0.05   799.0  621.0
# 15                      0.99                     0.05   798.0  615.0
# 4                       0.99                     0.05   782.0  614.0
# 8                       0.99                     0.05   845.0  605.0
# 3                       0.99                     0.05   831.0  602.0
# 10                      0.99                     0.05   880.0  596.0
# 12                      0.99                     0.05   836.0  591.0
# 1                       0.99                     0.05   788.0  591.0
# 2                       0.99                     0.05   814.0  587.0
# 28                      0.99                     0.05   894.0  583.0
# 17                      0.99                     0.05   850.0  583.0
# 29                      0.99                     0.05   922.0  581.0
# 21                      0.99                     0.05   889.0  581.0
# 26                      0.99                     0.05   913.0  577.0
# 25                      0.99                     0.05   904.0  574.0
# 23                      0.99                     0.05   898.0  572.0
# 31                      0.99                     0.05   916.0  570.0
# 20                      0.99                     0.05   864.0  568.0
# 18                      0.99                     0.05   840.0  567.0
# 5                       0.99                     0.05   861.0  565.0
# 34                      0.99                     0.05   922.0  562.0
# 40                      0.99                     0.05   943.0  553.0
# 30                      0.99                     0.05   918.0  551.0
# 37                      0.99                     0.05   951.0  550.0
# 24                      0.99                     0.05   901.0  542.0
# 19                      0.99                     0.05   879.0  540.0
# 42                      0.99                     0.05   937.0  537.0
# 36                      0.99                     0.05   953.0  533.0
# 38                      0.99                     0.05   995.0  464.0
# 44                      0.99                     0.05  1028.0  456.0
# 41                      0.99                     0.05  1018.0  449.0
# 43                      0.99                     0.05  1025.0  446.0
# 39                      0.99                     0.05  1026.0  443.0
# 33                      0.99                     0.05  1024.0  429.0
# 32                      0.99                     0.05  1022.0  423.0
# 22                      0.99                     0.05   969.0  422.0
# 27                      0.99                     0.05  1013.0  420.0
# 35                      0.99                     0.05  1015.0  415.0
# 14                      0.99                     0.05  1064.0  348.0
# 13                      0.99                     0.05  1072.0  339.0
# 9                       0.99                     0.05  1053.0  335.0
# 6                       0.99                     0.05  1034.0  317.0
# 16                      0.99                     0.05  1065.0  312.0

# %%
#Experimentamos variando el tamaño del train test
#KNN + PCA
import sys
from multiprocessing import Pool

def run_grid_in_parallel(grid, n_proc=18):
    """Run a grid on n_proc workers"""
    done, results = 0, []
    
    def call_back(out):
        nonlocal done
        nonlocal results
        results.append(out)
        done += 1
        print('\r', f'Point {done}/{len(grid)} done', end='         ')
        sys.stdout.flush()

    with Pool(n_proc) as pool:
        for point in grid:
            pool.apply_async(run, args=(EXEC_PATH, point, ), callback=call_back)
        pool.close()
        pool.join()
    return pd.DataFrame(results)

file_names = ['../data/train_test_sample_' + str(i) + '.csv' for i in range(1000,25001,1000)]
grid_ranges = {
    'dataset': file_names,
    'output_file': ['../../datos/out.csv'], # Todavia no hace nada
    'mode': [1],
    'k': [15],
    'alpha': [50],
    'threshold_frecuency_low': [0.05],
    'threshold_frecuency_high': [0.99],
}
grid = list(build_grid(grid_ranges))
res_3 = run_grid_in_parallel(grid)
# Out:
#  Point 25/25 done

# %%
res_3
# Out:
#     Accuracy                         Dataset File        F1  Precision  \
# 0     0.5944   ../data/train_test_sample_1000.csv  0.512500   0.422011
# 1     0.6156   ../data/train_test_sample_2000.csv  0.549883   0.468850
# 2     0.6344   ../data/train_test_sample_3000.csv  0.579190   0.505627
# 3     0.6344   ../data/train_test_sample_4000.csv  0.591234   0.546281
# 4     0.6232   ../data/train_test_sample_5000.csv  0.590791   0.544872
# 5     0.6364   ../data/train_test_sample_6000.csv  0.603230   0.541536
# 6     0.6548   ../data/train_test_sample_7000.csv  0.636019   0.583140
# 7     0.6340   ../data/train_test_sample_8000.csv  0.606113   0.583264
# 8     0.6444   ../data/train_test_sample_9000.csv  0.617634   0.582792
# 9     0.6272  ../data/train_test_sample_10000.csv  0.602050   0.555118
# 10    0.6424  ../data/train_test_sample_11000.csv  0.624685   0.599034
# 11    0.6640  ../data/train_test_sample_12000.csv  0.640411   0.604689
# 12    0.6508  ../data/train_test_sample_13000.csv  0.631801   0.605497
# 13    0.6584  ../data/train_test_sample_14000.csv  0.637829   0.593060
# 14    0.6420  ../data/train_test_sample_15000.csv  0.620923   0.581746
# 15    0.6432  ../data/train_test_sample_16000.csv  0.630489   0.610265
# 16    0.6320  ../data/train_test_sample_17000.csv  0.607173   0.560726
# 17    0.6504  ../data/train_test_sample_18000.csv  0.624248   0.576648
# 18    0.6412  ../data/train_test_sample_19000.csv  0.614856   0.573259
# 19    0.6640  ../data/train_test_sample_20000.csv  0.652318   0.609435
# 20    0.6572  ../data/train_test_sample_21000.csv  0.638549   0.598419
# 21    0.6408  ../data/train_test_sample_22000.csv  0.627695   0.593725
# 22    0.6624  ../data/train_test_sample_23000.csv  0.632724   0.595902
# 23    0.6560  ../data/train_test_sample_24000.csv  0.632792   0.599515
# 24    0.6764  ../data/train_test_sample_25000.csv  0.661931   0.624606
#
#       Recall      Time  alpha     fn     fp     k  mode  \
# 0   0.652387   9.78971   50.0  730.0  284.0  15.0   1.0
# 1   0.664779  11.28900   50.0  665.0  296.0  15.0   1.0
# 2   0.677802  13.22350   50.0  615.0  299.0  15.0   1.0
# 3   0.644250  15.12680   50.0  549.0  365.0  15.0   1.0
# 4   0.645161  16.55210   50.0  568.0  374.0  15.0   1.0
# 5   0.680788  18.19010   50.0  585.0  324.0  15.0   1.0
# 6   0.699443  19.40850   50.0  539.0  324.0  15.0   1.0
# 7   0.630824  20.79220   50.0  503.0  412.0  15.0   1.0
# 8   0.656908  21.73680   50.0  514.0  375.0  15.0   1.0
# 9   0.657649  22.86240   50.0  565.0  367.0  15.0   1.0
# 10  0.652632  24.13070   50.0  498.0  396.0  15.0   1.0
# 11  0.680619  25.13650   50.0  489.0  351.0  15.0   1.0
# 12  0.660494  26.47520   50.0  488.0  385.0  15.0   1.0
# 13  0.689908  27.39060   50.0  516.0  338.0  15.0   1.0
# 14  0.665758  28.19740   50.0  527.0  368.0  15.0   1.0
# 15  0.652099  29.42430   50.0  486.0  406.0  15.0   1.0
# 16  0.662011  30.14050   50.0  557.0  363.0  15.0   1.0
# 17  0.680412  30.84100   50.0  533.0  341.0  15.0   1.0
# 18  0.662963  29.53800   50.0  533.0  364.0  15.0   1.0
# 19  0.701692  30.31880   50.0  505.0  335.0  15.0   1.0
# 20  0.684448  31.34860   50.0  508.0  349.0  15.0   1.0
# 21  0.665787  32.14010   50.0  518.0  380.0  15.0   1.0
# 22  0.674397  32.79930   50.0  493.0  351.0  15.0   1.0
# 23  0.669982  32.85980   50.0  495.0  365.0  15.0   1.0
# 24  0.704000  33.08070   50.0  476.0  333.0  15.0   1.0
#
#     threshold_frecuency_high  threshold_frecuency_low     tn     tp
# 0                       0.99                     0.05  953.0  533.0
# 1                       0.99                     0.05  952.0  587.0
# 2                       0.99                     0.05  957.0  629.0
# 3                       0.99                     0.05  925.0  661.0
# 4                       0.99                     0.05  878.0  680.0
# 5                       0.99                     0.05  900.0  691.0
# 6                       0.99                     0.05  883.0  754.0
# 7                       0.99                     0.05  881.0  704.0
# 8                       0.99                     0.05  893.0  718.0
# 9                       0.99                     0.05  863.0  705.0
# 10                      0.99                     0.05  862.0  744.0
# 11                      0.99                     0.05  912.0  748.0
# 12                      0.99                     0.05  878.0  749.0
# 13                      0.99                     0.05  894.0  752.0
# 14                      0.99                     0.05  872.0  733.0
# 15                      0.99                     0.05  847.0  761.0
# 16                      0.99                     0.05  869.0  711.0
# 17                      0.99                     0.05  900.0  726.0
# 18                      0.99                     0.05  887.0  716.0
# 19                      0.99                     0.05  872.0  788.0
# 20                      0.99                     0.05  886.0  757.0
# 21                      0.99                     0.05  845.0  757.0
# 22                      0.99                     0.05  929.0  727.0
# 23                      0.99                     0.05  899.0  741.0
# 24                      0.99                     0.05  899.0  792.0

# %%
res_3.to_csv('KNN_PCA_TrainTestSize.csv')

# %%
#Experimentamos variando el tamaño del train test
#KNN
import sys
from multiprocessing import Pool

def run_grid_in_parallel(grid, n_proc=18):
    """Run a grid on n_proc workers"""
    done, results = 0, []
    
    def call_back(out):
        nonlocal done
        nonlocal results
        results.append(out)
        done += 1
        print('\r', f'Point {done}/{len(grid)} done', end='         ')
        sys.stdout.flush()

    with Pool(n_proc) as pool:
        for point in grid:
            pool.apply_async(run, args=(EXEC_PATH, point, ), callback=call_back)
        pool.close()
        pool.join()
    return pd.DataFrame(results)

file_names = ['../data/train_test_sample_' + str(i) + '.csv' for i in range(1000,25001,1000)]
grid_ranges = {
    'dataset': file_names,
    'output_file': ['../../datos/out.csv'], # Todavia no hace nada
    'mode': [0],
    'k': [15],
    'alpha': [0],
    'threshold_frecuency_low': [0.05],
    'threshold_frecuency_high': [0.99],
}
grid = list(build_grid(grid_ranges))
res_4 = run_grid_in_parallel(grid)
# Out:
#  Point 25/25 done

# %%
res_4
# Out:
#     Accuracy                         Dataset File        F1  Precision  \
# 0     0.5848   ../data/train_test_sample_1000.csv  0.495136   0.403009
# 1     0.6052   ../data/train_test_sample_2000.csv  0.511144   0.412141
# 2     0.6396   ../data/train_test_sample_3000.csv  0.583063   0.506431
# 3     0.6356   ../data/train_test_sample_4000.csv  0.574895   0.509091
# 4     0.6312   ../data/train_test_sample_5000.csv  0.588393   0.528045
# 5     0.6112   ../data/train_test_sample_6000.csv  0.586383   0.539969
# 6     0.6480   ../data/train_test_sample_7000.csv  0.626486   0.570766
# 7     0.6440   ../data/train_test_sample_8000.csv  0.607237   0.570008
# 8     0.6412   ../data/train_test_sample_9000.csv  0.624529   0.605519
# 9     0.6296  ../data/train_test_sample_10000.csv  0.603935   0.555906
# 10    0.6456  ../data/train_test_sample_11000.csv  0.613775   0.566828
# 11    0.6464  ../data/train_test_sample_12000.csv  0.612281   0.564268
# 12    0.6432  ../data/train_test_sample_13000.csv  0.620102   0.588521
# 13    0.6636  ../data/train_test_sample_14000.csv  0.639211   0.587539
# 14    0.6452  ../data/train_test_sample_15000.csv  0.616515   0.565873
# 15    0.6380  ../data/train_test_sample_16000.csv  0.613083   0.574980
# 16    0.6256  ../data/train_test_sample_17000.csv  0.586207   0.522871
# 17    0.6572  ../data/train_test_sample_18000.csv  0.616898   0.548054
# 18    0.6524  ../data/train_test_sample_19000.csv  0.614292   0.554043
# 19    0.6636  ../data/train_test_sample_20000.csv  0.640752   0.580046
# 20    0.6396  ../data/train_test_sample_21000.csv  0.608090   0.552569
# 21    0.6476  ../data/train_test_sample_22000.csv  0.615452   0.552941
# 22    0.6516  ../data/train_test_sample_23000.csv  0.609242   0.556557
# 23    0.6596  ../data/train_test_sample_24000.csv  0.624614   0.572816
# 24    0.6664  ../data/train_test_sample_25000.csv  0.640827   0.586751
#
#       Recall      Time  alpha     fn     fp     k  mode  \
# 0   0.641866   1.63204    0.0  754.0  284.0  15.0   0.0
# 1   0.672751   3.87094    0.0  736.0  251.0  15.0   0.0
# 2   0.687023   6.20983    0.0  614.0  287.0  15.0   0.0
# 3   0.660236   8.40499    0.0  594.0  317.0  15.0   0.0
# 4   0.664315  10.67270    0.0  589.0  333.0  15.0   0.0
# 5   0.641527  12.76480    0.0  587.0  385.0  15.0   0.0
# 6   0.694262  14.91220    0.0  555.0  325.0  15.0   0.0
# 7   0.649669  17.27330    0.0  519.0  371.0  15.0   0.0
# 8   0.644771  19.33170    0.0  486.0  411.0  15.0   0.0
# 9   0.661049  21.34940    0.0  564.0  362.0  15.0   0.0
# 10  0.669202  23.30920    0.0  538.0  348.0  15.0   0.0
# 11  0.669223  24.95170    0.0  539.0  345.0  15.0   0.0
# 12  0.655266  26.87840    0.0  509.0  383.0  15.0   0.0
# 13  0.700847  28.54840    0.0  523.0  318.0  15.0   0.0
# 14  0.677113  30.33250    0.0  547.0  340.0  15.0   0.0
# 15  0.656593  31.65590    0.0  530.0  375.0  15.0   0.0
# 16  0.667002  33.82250    0.0  605.0  331.0  15.0   0.0
# 17  0.705521  35.25300    0.0  569.0  288.0  15.0   0.0
# 18  0.689243  35.73840    0.0  557.0  312.0  15.0   0.0
# 19  0.715649  36.49590    0.0  543.0  298.0  15.0   0.0
# 20  0.676015  37.02790    0.0  566.0  335.0  15.0   0.0
# 21  0.693898  37.58140    0.0  570.0  311.0  15.0   0.0
# 22  0.672944  38.22050    0.0  541.0  330.0  15.0   0.0
# 23  0.686712  38.54590    0.0  528.0  323.0  15.0   0.0
# 24  0.705882  39.34960    0.0  524.0  310.0  15.0   0.0
#
#     threshold_frecuency_high  threshold_frecuency_low     tn     tp
# 0                       0.99                     0.05  953.0  509.0
# 1                       0.99                     0.05  997.0  516.0
# 2                       0.99                     0.05  969.0  630.0
# 3                       0.99                     0.05  973.0  616.0
# 4                       0.99                     0.05  919.0  659.0
# 5                       0.99                     0.05  839.0  689.0
# 6                       0.99                     0.05  882.0  738.0
# 7                       0.99                     0.05  922.0  688.0
# 8                       0.99                     0.05  857.0  746.0
# 9                       0.99                     0.05  868.0  706.0
# 10                      0.99                     0.05  910.0  704.0
# 11                      0.99                     0.05  918.0  698.0
# 12                      0.99                     0.05  880.0  728.0
# 13                      0.99                     0.05  914.0  745.0
# 14                      0.99                     0.05  900.0  713.0
# 15                      0.99                     0.05  878.0  717.0
# 16                      0.99                     0.05  901.0  663.0
# 17                      0.99                     0.05  953.0  690.0
# 18                      0.99                     0.05  939.0  692.0
# 19                      0.99                     0.05  909.0  750.0
# 20                      0.99                     0.05  900.0  699.0
# 21                      0.99                     0.05  914.0  705.0
# 22                      0.99                     0.05  950.0  679.0
# 23                      0.99                     0.05  941.0  708.0
# 24                      0.99                     0.05  922.0  744.0

# %%
res_4.to_csv('KNN_TrainTestSize.csv')

# %%
#Como se relaciona k con el tamaño del training set

# %%
#Experimentamos variando el tamaño del train test y k
#KNN + PCA

import sys
from multiprocessing import Pool

def run_grid_in_parallel(grid, n_proc=18):
    """Run a grid on n_proc workers"""
    done, results = 0, []
    
    def call_back(out):
        nonlocal done
        nonlocal results
        results.append(out)
        done += 1
        print('\r', f'Point {done}/{len(grid)} done', end='         ')
        sys.stdout.flush()

    with Pool(n_proc) as pool:
        for point in grid:
            pool.apply_async(run, args=(EXEC_PATH, point, ), callback=call_back)
        pool.close()
        pool.join()
    return pd.DataFrame(results)

file_names = ['../data/train_test_sample_' + str(i) + '.csv' for i in range(1000,25001,2000)]
grid_ranges = {
    'dataset': file_names,
    'output_file': ['../../datos/out.csv'], # Todavia no hace nada
    'mode': [1],
    'k': [1, 2, 3, 5, 7, 9, 10, 15, 20, 50, 100, 250, 500],
    'alpha': [50],
    'threshold_frecuency_low': [0.05],
    'threshold_frecuency_high': [0.99],
}
grid = list(build_grid(grid_ranges))
res_5 = run_grid_in_parallel(grid)
# Out:
#  Point 169/169 done

# %%
res_5
# Out:
#      Accuracy                         Dataset File        F1  Precision  \
# 0      0.6024   ../data/train_test_sample_1000.csv  0.469584   0.348377
# 1      0.5552   ../data/train_test_sample_1000.csv  0.375982   0.265241
# 2      0.5944   ../data/train_test_sample_1000.csv  0.512500   0.422011
# 3      0.5732   ../data/train_test_sample_1000.csv  0.440482   0.332542
# 4      0.5704   ../data/train_test_sample_1000.csv  0.512704   0.447348
# 5      0.5584   ../data/train_test_sample_1000.csv  0.526587   0.486144
# 6      0.5568   ../data/train_test_sample_1000.csv  0.306633   0.193983
# 7      0.5772   ../data/train_test_sample_1000.csv  0.506305   0.429137
# 8      0.5800   ../data/train_test_sample_1000.csv  0.371257   0.245447
# 9      0.5876   ../data/train_test_sample_1000.csv  0.462180   0.350752
# 10     0.6032   ../data/train_test_sample_1000.csv  0.446429   0.316706
# 11     0.5732   ../data/train_test_sample_1000.csv  0.530163   0.476643
# 12     0.5676   ../data/train_test_sample_1000.csv  0.499769   0.427553
# 13     0.6212   ../data/train_test_sample_3000.csv  0.578924   0.523312
# 14     0.5964   ../data/train_test_sample_3000.csv  0.568988   0.535370
# 15     0.6084   ../data/train_test_sample_3000.csv  0.574163   0.530547
# 16     0.5936   ../data/train_test_sample_3000.csv  0.579818   0.563505
# 17     0.5748   ../data/train_test_sample_3000.csv  0.418172   0.307074
# 18     0.6260   ../data/train_test_sample_3000.csv  0.524173   0.413987
# 19     0.6220   ../data/train_test_sample_3000.csv  0.531947   0.431672
# 20     0.6188   ../data/train_test_sample_3000.csv  0.521826   0.418006
# 21     0.6104   ../data/train_test_sample_3000.csv  0.476344   0.356109
# 22     0.6344   ../data/train_test_sample_3000.csv  0.579190   0.505627
# 23     0.5952   ../data/train_test_sample_3000.csv  0.422374   0.297428
# 24     0.6196   ../data/train_test_sample_3000.csv  0.504945   0.389871
# 25     0.6164   ../data/train_test_sample_3000.csv  0.565473   0.501608
# 26     0.5712   ../data/train_test_sample_5000.csv  0.557756   0.541667
# 27     0.6056   ../data/train_test_sample_5000.csv  0.584317   0.555288
# 28     0.6088   ../data/train_test_sample_5000.csv  0.585593   0.553686
# 29     0.5996   ../data/train_test_sample_5000.csv  0.578526   0.550481
# ..        ...                                  ...       ...        ...
# 139    0.6652  ../data/train_test_sample_21000.csv  0.631115   0.566008
# 140    0.6528  ../data/train_test_sample_21000.csv  0.610762   0.538340
# 141    0.6560  ../data/train_test_sample_21000.csv  0.610154   0.532016
# 142    0.6416  ../data/train_test_sample_21000.csv  0.589368   0.508300
# 143    0.6036  ../data/train_test_sample_23000.csv  0.591003   0.586885
# 144    0.5916  ../data/train_test_sample_23000.csv  0.451959   0.345082
# 145    0.6196  ../data/train_test_sample_23000.csv  0.597886   0.579508
# 146    0.6396  ../data/train_test_sample_23000.csv  0.613802   0.586885
# 147    0.6440  ../data/train_test_sample_23000.csv  0.616379   0.586066
# 148    0.6452  ../data/train_test_sample_23000.csv  0.617837   0.587705
# 149    0.6364  ../data/train_test_sample_23000.csv  0.573440   0.500820
# 150    0.6624  ../data/train_test_sample_23000.csv  0.632724   0.595902
# 151    0.6652  ../data/train_test_sample_23000.csv  0.613752   0.545082
# 152    0.6744  ../data/train_test_sample_23000.csv  0.624539   0.554918
# 153    0.6692  ../data/train_test_sample_23000.csv  0.613732   0.538525
# 154    0.6664  ../data/train_test_sample_23000.csv  0.605860   0.525410
# 155    0.6556  ../data/train_test_sample_23000.csv  0.587050   0.501639
# 156    0.5920  ../data/train_test_sample_25000.csv  0.589041   0.576498
# 157    0.5788  ../data/train_test_sample_25000.csv  0.462481   0.357256
# 158    0.6068  ../data/train_test_sample_25000.csv  0.603149   0.589117
# 159    0.6380  ../data/train_test_sample_25000.csv  0.632263   0.613565
# 160    0.6480  ../data/train_test_sample_25000.csv  0.639344   0.615142
# 161    0.6584  ../data/train_test_sample_25000.csv  0.651997   0.630915
# 162    0.6464  ../data/train_test_sample_25000.csv  0.604651   0.533123
# 163    0.6764  ../data/train_test_sample_25000.csv  0.661931   0.624606
# 164    0.6652  ../data/train_test_sample_25000.csv  0.631115   0.564669
# 165    0.6760  ../data/train_test_sample_25000.csv  0.645048   0.580442
# 166    0.6716  ../data/train_test_sample_25000.csv  0.637528   0.569401
# 167    0.6680  ../data/train_test_sample_25000.csv  0.630454   0.558360
# 168    0.6520  ../data/train_test_sample_25000.csv  0.604905   0.525237
#
#        Recall      Time  alpha      fn     fp      k  mode  \
# 0    0.720131   9.67878   50.0   823.0  171.0   50.0   1.0
# 1    0.645472   9.69777   50.0   928.0  184.0    2.0   1.0
# 2    0.652387   9.69876   50.0   730.0  284.0   15.0   1.0
# 3    0.652174   9.69159   50.0   843.0  224.0   10.0   1.0
# 4    0.600425   9.71188   50.0   698.0  376.0    5.0   1.0
# 5    0.574369   9.72201   50.0   649.0  455.0    1.0   1.0
# 6    0.731343   9.72193   50.0  1018.0   90.0  500.0   1.0
# 7    0.617312   9.72454   50.0   721.0  336.0    9.0   1.0
# 8    0.761671   9.72841   50.0   953.0   97.0  250.0   1.0
# 9    0.677370   9.72138   50.0   820.0  211.0   20.0   1.0
# 10   0.756144   9.73785   50.0   863.0  129.0  100.0   1.0
# 11   0.597222   9.74002   50.0   661.0  406.0    3.0   1.0
# 12   0.601336   9.77475   50.0   723.0  358.0    7.0   1.0
# 13   0.647761  12.94840   50.0   593.0  354.0    7.0   1.0
# 14   0.607110  12.97420   50.0   578.0  431.0    3.0   1.0
# 15   0.625592  12.98940   50.0   584.0  395.0    5.0   1.0
# 16   0.597104  12.99550   50.0   543.0  473.0    1.0   1.0
# 17   0.655232  13.00490   50.0   862.0  201.0    2.0   1.0
# 18   0.714286  12.93130   50.0   729.0  206.0   50.0   1.0
# 19   0.692903  12.99400   50.0   707.0  238.0   20.0   1.0
# 20   0.694259  13.00860   50.0   724.0  229.0   10.0   1.0
# 21   0.719156  12.98130   50.0   801.0  173.0  250.0   1.0
# 22   0.677802  13.05340   50.0   615.0  299.0   15.0   1.0
# 23   0.728346  13.03270   50.0   874.0  138.0  500.0   1.0
# 24   0.716396  13.07690   50.0   759.0  192.0  100.0   1.0
# 25   0.647975  13.27600   50.0   620.0  339.0    9.0   1.0
# 26   0.574830  16.17560   50.0   572.0  500.0    1.0   1.0
# 27   0.616548  16.16620   50.0   555.0  431.0    5.0   1.0
# 28   0.621403  16.15960   50.0   557.0  421.0    7.0   1.0
# 29   0.609583  16.23910   50.0   561.0  440.0    3.0   1.0
# ..        ...       ...    ...     ...    ...    ...   ...
# 139  0.713147  35.39430   50.0   549.0  288.0   50.0   1.0
# 140  0.705699  35.38230   50.0   584.0  284.0  100.0   1.0
# 141  0.715197  35.14530   50.0   592.0  268.0  250.0   1.0
# 142  0.701200  34.94040   50.0   622.0  274.0  500.0   1.0
# 143  0.595179  37.55480   50.0   504.0  487.0    1.0   1.0
# 144  0.654743  37.37590   50.0   799.0  222.0    2.0   1.0
# 145  0.617467  37.24890   50.0   513.0  438.0    3.0   1.0
# 146  0.643306  37.38660   50.0   504.0  397.0    5.0   1.0
# 147  0.650000  37.39680   50.0   505.0  385.0    7.0   1.0
# 148  0.651226  37.51430   50.0   503.0  384.0    9.0   1.0
# 149  0.670692  37.52800   50.0   609.0  300.0   10.0   1.0
# 150  0.674397  37.69730   50.0   493.0  351.0   15.0   1.0
# 151  0.702218  37.52020   50.0   555.0  282.0   20.0   1.0
# 152  0.714135  37.62030   50.0   543.0  271.0   50.0   1.0
# 153  0.713355  37.68320   50.0   563.0  264.0  100.0   1.0
# 154  0.715402  37.63210   50.0   579.0  255.0  250.0   1.0
# 155  0.707514  37.41070   50.0   608.0  253.0  500.0   1.0
# 156  0.602142  39.26070   50.0   537.0  483.0    1.0   1.0
# 157  0.655572  39.37640   50.0   815.0  238.0    2.0   1.0
# 158  0.617866  39.13620   50.0   521.0  462.0    3.0   1.0
# 159  0.652137  39.04790   50.0   490.0  415.0    5.0   1.0
# 160  0.665529  38.75060   50.0   488.0  392.0    7.0   1.0
# 161  0.674536  38.24940   50.0   468.0  386.0    9.0   1.0
# 162  0.698347  37.25580   50.0   592.0  292.0   10.0   1.0
# 163  0.704000  36.76290   50.0   476.0  333.0   15.0   1.0
# 164  0.715285  36.83780   50.0   552.0  285.0   20.0   1.0
# 165  0.725838  35.94430   50.0   532.0  278.0   50.0   1.0
# 166  0.724173  35.65130   50.0   546.0  275.0  100.0   1.0
# 167  0.723926  35.38650   50.0   560.0  270.0  250.0   1.0
# 168  0.713062  33.74740   50.0   602.0  268.0  500.0   1.0
#
#      threshold_frecuency_high  threshold_frecuency_low      tn     tp
# 0                        0.99                     0.05  1066.0  440.0
# 1                        0.99                     0.05  1053.0  335.0
# 2                        0.99                     0.05   953.0  533.0
# 3                        0.99                     0.05  1013.0  420.0
# 4                        0.99                     0.05   861.0  565.0
# 5                        0.99                     0.05   782.0  614.0
# 6                        0.99                     0.05  1147.0  245.0
# 7                        0.99                     0.05   901.0  542.0
# 8                        0.99                     0.05  1140.0  310.0
# 9                        0.99                     0.05  1026.0  443.0
# 10                       0.99                     0.05  1108.0  400.0
# 11                       0.99                     0.05   831.0  602.0
# 12                       0.99                     0.05   879.0  540.0
# 13                       0.99                     0.05   902.0  651.0
# 14                       0.99                     0.05   825.0  666.0
# 15                       0.99                     0.05   861.0  660.0
# 16                       0.99                     0.05   783.0  701.0
# 17                       0.99                     0.05  1055.0  382.0
# 18                       0.99                     0.05  1050.0  515.0
# 19                       0.99                     0.05  1018.0  537.0
# 20                       0.99                     0.05  1027.0  520.0
# 21                       0.99                     0.05  1083.0  443.0
# 22                       0.99                     0.05   957.0  629.0
# 23                       0.99                     0.05  1118.0  370.0
# 24                       0.99                     0.05  1064.0  485.0
# 25                       0.99                     0.05   917.0  624.0
# 26                       0.99                     0.05   752.0  676.0
# 27                       0.99                     0.05   821.0  693.0
# 28                       0.99                     0.05   831.0  691.0
# 29                       0.99                     0.05   812.0  687.0
# ..                        ...                      ...     ...    ...
# 139                      0.99                     0.05   947.0  716.0
# 140                      0.99                     0.05   951.0  681.0
# 141                      0.99                     0.05   967.0  673.0
# 142                      0.99                     0.05   961.0  643.0
# 143                      0.99                     0.05   793.0  716.0
# 144                      0.99                     0.05  1058.0  421.0
# 145                      0.99                     0.05   842.0  707.0
# 146                      0.99                     0.05   883.0  716.0
# 147                      0.99                     0.05   895.0  715.0
# 148                      0.99                     0.05   896.0  717.0
# 149                      0.99                     0.05   980.0  611.0
# 150                      0.99                     0.05   929.0  727.0
# 151                      0.99                     0.05   998.0  665.0
# 152                      0.99                     0.05  1009.0  677.0
# 153                      0.99                     0.05  1016.0  657.0
# 154                      0.99                     0.05  1025.0  641.0
# 155                      0.99                     0.05  1027.0  612.0
# 156                      0.99                     0.05   749.0  731.0
# 157                      0.99                     0.05   994.0  453.0
# 158                      0.99                     0.05   770.0  747.0
# 159                      0.99                     0.05   817.0  778.0
# 160                      0.99                     0.05   840.0  780.0
# 161                      0.99                     0.05   846.0  800.0
# 162                      0.99                     0.05   940.0  676.0
# 163                      0.99                     0.05   899.0  792.0
# 164                      0.99                     0.05   947.0  716.0
# 165                      0.99                     0.05   954.0  736.0
# 166                      0.99                     0.05   957.0  722.0
# 167                      0.99                     0.05   962.0  708.0
# 168                      0.99                     0.05   964.0  666.0
#
# [169 rows x 15 columns]

# %%
res_5.to_csv('KNN_PCA_TrainTestSize_and_K.csv')

# %%
#Experimentamos variando el tamaño del train test y k
#KNN

import sys
from multiprocessing import Pool

def run_grid_in_parallel(grid, n_proc=18):
    """Run a grid on n_proc workers"""
    done, results = 0, []
    
    def call_back(out):
        nonlocal done
        nonlocal results
        results.append(out)
        done += 1
        print('\r', f'Point {done}/{len(grid)} done', end='         ')
        sys.stdout.flush()

    with Pool(n_proc) as pool:
        for point in grid:
            pool.apply_async(run, args=(EXEC_PATH, point, ), callback=call_back)
        pool.close()
        pool.join()
    return pd.DataFrame(results)

file_names = ['../data/train_test_sample_' + str(i) + '.csv' for i in range(1000,25001,2000)]
grid_ranges = {
    'dataset': file_names,
    'output_file': ['../../datos/out.csv'], # Todavia no hace nada
    'mode': [0],
    'k': [1, 2, 3, 5, 7, 9, 10, 15, 20, 50, 100, 250, 500],
    'alpha': [0],
    'threshold_frecuency_low': [0.05],
    'threshold_frecuency_high': [0.99],
}
grid = list(build_grid(grid_ranges))
res_6 = run_grid_in_parallel(grid)
# Out:
#  Point 169/169 done

# %%
res_6
# Out:
#      Accuracy                         Dataset File        F1  Precision  \
# 0      0.6096   ../data/train_test_sample_1000.csv  0.455357   0.323040
# 1      0.5864   ../data/train_test_sample_1000.csv  0.451750   0.337292
# 2      0.5844   ../data/train_test_sample_1000.csv  0.521419   0.448139
# 3      0.5920   ../data/train_test_sample_1000.csv  0.511962   0.423595
# 4      0.5544   ../data/train_test_sample_1000.csv  0.356069   0.243864
# 5      0.5768   ../data/train_test_sample_1000.csv  0.519091   0.452098
# 6      0.5632   ../data/train_test_sample_1000.csv  0.521053   0.470309
# 7      0.5828   ../data/train_test_sample_1000.csv  0.507787   0.425970
# 8      0.5848   ../data/train_test_sample_1000.csv  0.495136   0.403009
# 9      0.5748   ../data/train_test_sample_1000.csv  0.348253   0.224861
# 10     0.6004   ../data/train_test_sample_1000.csv  0.470588   0.351544
# 11     0.5772   ../data/train_test_sample_1000.csv  0.437467   0.325416
# 12     0.5508   ../data/train_test_sample_1000.csv  0.274079   0.167854
# 13     0.6332   ../data/train_test_sample_3000.csv  0.594427   0.540193
# 14     0.5740   ../data/train_test_sample_3000.csv  0.420881   0.311093
# 15     0.5840   ../data/train_test_sample_3000.csv  0.570957   0.556270
# 16     0.6264   ../data/train_test_sample_3000.csv  0.600171   0.563505
# 17     0.6172   ../data/train_test_sample_3000.csv  0.595349   0.565916
# 18     0.6396   ../data/train_test_sample_3000.csv  0.583063   0.506431
# 19     0.6004   ../data/train_test_sample_3000.csv  0.451400   0.330386
# 20     0.6168   ../data/train_test_sample_3000.csv  0.493122   0.374598
# 21     0.6352   ../data/train_test_sample_3000.csv  0.592129   0.532154
# 22     0.6252   ../data/train_test_sample_3000.csv  0.530796   0.426045
# 23     0.6312   ../data/train_test_sample_3000.csv  0.545813   0.445338
# 24     0.6232   ../data/train_test_sample_3000.csv  0.512927   0.398714
# 25     0.5924   ../data/train_test_sample_3000.csv  0.409275   0.283762
# 26     0.5800   ../data/train_test_sample_5000.csv  0.434876   0.323718
# 27     0.6032   ../data/train_test_sample_5000.csv  0.576430   0.540865
# 28     0.6056   ../data/train_test_sample_5000.csv  0.567923   0.519231
# 29     0.6040   ../data/train_test_sample_5000.csv  0.571799   0.529647
# ..        ...                                  ...       ...        ...
# 139    0.6460  ../data/train_test_sample_21000.csv  0.593103   0.509881
# 140    0.6408  ../data/train_test_sample_21000.csv  0.578404   0.486957
# 141    0.6368  ../data/train_test_sample_21000.csv  0.574109   0.483794
# 142    0.6328  ../data/train_test_sample_21000.csv  0.564103   0.469565
# 143    0.6024  ../data/train_test_sample_23000.csv  0.582002   0.567213
# 144    0.5948  ../data/train_test_sample_23000.csv  0.445539   0.333607
# 145    0.6308  ../data/train_test_sample_23000.csv  0.604711   0.578689
# 146    0.6472  ../data/train_test_sample_23000.csv  0.615854   0.579508
# 147    0.6516  ../data/train_test_sample_23000.csv  0.621140   0.585246
# 148    0.6544  ../data/train_test_sample_23000.csv  0.619048   0.575410
# 149    0.6508  ../data/train_test_sample_23000.csv  0.577240   0.488525
# 150    0.6548  ../data/train_test_sample_23000.csv  0.591576   0.512295
# 151    0.6516  ../data/train_test_sample_23000.csv  0.609242   0.556557
# 152    0.6712  ../data/train_test_sample_23000.csv  0.604808   0.515574
# 153    0.6572  ../data/train_test_sample_23000.csv  0.588574   0.502459
# 154    0.6560  ../data/train_test_sample_23000.csv  0.576772   0.480328
# 155    0.6508  ../data/train_test_sample_23000.csv  0.567179   0.468852
# 156    0.5928  ../data/train_test_sample_25000.csv  0.583470   0.562303
# 157    0.5892  ../data/train_test_sample_25000.csv  0.468151   0.356467
# 158    0.6300  ../data/train_test_sample_25000.csv  0.615065   0.582808
# 159    0.6456  ../data/train_test_sample_25000.csv  0.628667   0.591483
# 160    0.6568  ../data/train_test_sample_25000.csv  0.637669   0.595426
# 161    0.6580  ../data/train_test_sample_25000.csv  0.639393   0.597792
# 162    0.6420  ../data/train_test_sample_25000.csv  0.589638   0.507098
# 163    0.6664  ../data/train_test_sample_25000.csv  0.640827   0.586751
# 164    0.6580  ../data/train_test_sample_25000.csv  0.610123   0.527603
# 165    0.6612  ../data/train_test_sample_25000.csv  0.614123   0.531546
# 166    0.6592  ../data/train_test_sample_25000.csv  0.608096   0.521293
# 167    0.6452  ../data/train_test_sample_25000.csv  0.587250   0.497634
# 168    0.6416  ../data/train_test_sample_25000.csv  0.578947   0.485804
#
#        Recall      Time  alpha      fn     fp      k  mode  \
# 0    0.771267   1.78221    0.0   855.0  121.0  100.0   0.0
# 1    0.683788   1.78067    0.0   837.0  197.0   20.0   0.0
# 2    0.623348   1.80168    0.0   697.0  342.0    5.0   0.0
# 3    0.646917   1.81217    0.0   728.0  292.0    9.0   0.0
# 4    0.659529   1.81915    0.0   955.0  159.0    2.0   0.0
# 5    0.609392   1.83706    0.0   692.0  366.0    3.0   0.0
# 6    0.584071   1.83777    0.0   669.0  423.0    1.0   0.0
# 7    0.628505   1.83631    0.0   725.0  318.0    7.0   0.0
# 8    0.641866   1.84645    0.0   754.0  284.0   15.0   0.0
# 9    0.771739   1.85083    0.0   979.0   84.0  250.0   0.0
# 10   0.711538   1.85665    0.0   819.0  180.0   50.0   0.0
# 11   0.667208   1.86535    0.0   852.0  205.0   10.0   0.0
# 12   0.746479   1.87118    0.0  1051.0   72.0  500.0   0.0
# 13   0.660767   6.01350    0.0   572.0  345.0    7.0   0.0
# 14   0.650420   6.03884    0.0   857.0  208.0    2.0   0.0
# 15   0.586441   6.10070    0.0   552.0  488.0    1.0   0.0
# 16   0.641941   6.13852    0.0   543.0  391.0    5.0   0.0
# 17   0.628011   6.16776    0.0   540.0  417.0    3.0   0.0
# 18   0.687023   6.27656    0.0   614.0  287.0   15.0   0.0
# 19   0.712305   6.31748    0.0   833.0  166.0  250.0   0.0
# 20   0.721362   6.34235    0.0   778.0  180.0  100.0   0.0
# 21   0.667339   6.38795    0.0   582.0  330.0    9.0   0.0
# 22   0.703851   6.36171    0.0   714.0  223.0   20.0   0.0
# 23   0.704835   6.39328    0.0   690.0  232.0   10.0   0.0
# 24   0.718841   6.41588    0.0   748.0  194.0   50.0   0.0
# 25   0.733888   6.46391    0.0   891.0  128.0  500.0   0.0
# 26   0.662295  10.55450    0.0   844.0  206.0    2.0   0.0
# 27   0.617002  10.62040    0.0   573.0  419.0    3.0   0.0
# 28   0.626692  10.56000    0.0   600.0  386.0    7.0   0.0
# 29   0.621241  10.63700    0.0   587.0  403.0    5.0   0.0
# ..        ...       ...    ...     ...    ...    ...   ...
# 139  0.708791  48.15640    0.0   620.0  265.0   50.0   0.0
# 140  0.712139  48.17950    0.0   649.0  249.0  100.0   0.0
# 141  0.705882  48.15350    0.0   653.0  255.0  250.0   0.0
# 142  0.706302  47.99330    0.0   671.0  247.0  500.0   0.0
# 143  0.597582  52.71930    0.0   528.0  466.0    1.0   0.0
# 144  0.670511  52.63250    0.0   813.0  200.0    2.0   0.0
# 145  0.633184  52.94610    0.0   514.0  409.0    3.0   0.0
# 146  0.657063  52.83980    0.0   513.0  369.0    5.0   0.0
# 147  0.661724  52.70450    0.0   506.0  365.0    7.0   0.0
# 148  0.669847  53.02550    0.0   518.0  346.0    9.0   0.0
# 149  0.705325  53.07800    0.0   624.0  249.0   10.0   0.0
# 150  0.699888  52.72870    0.0   595.0  268.0   20.0   0.0
# 151  0.672944  53.00100    0.0   541.0  330.0   15.0   0.0
# 152  0.731395  52.50920    0.0   591.0  231.0   50.0   0.0
# 153  0.710313  52.61330    0.0   607.0  250.0  100.0   0.0
# 154  0.721675  52.05940    0.0   634.0  226.0  250.0   0.0
# 155  0.717691  51.31820    0.0   648.0  225.0  500.0   0.0
# 156  0.606293  55.04690    0.0   555.0  463.0    1.0   0.0
# 157  0.681750  54.09870    0.0   816.0  211.0    2.0   0.0
# 158  0.651101  52.55420    0.0   529.0  396.0    3.0   0.0
# 159  0.670841  53.00810    0.0   518.0  368.0    5.0   0.0
# 160  0.686364  51.67060    0.0   513.0  345.0    7.0   0.0
# 161  0.687217  50.06290    0.0   510.0  345.0    9.0   0.0
# 162  0.704272  49.33550    0.0   625.0  270.0   10.0   0.0
# 163  0.705882  47.29850    0.0   524.0  310.0   15.0   0.0
# 164  0.723243  47.18240    0.0   599.0  256.0   20.0   0.0
# 165  0.727077  46.10510    0.0   594.0  253.0   50.0   0.0
# 166  0.729581  44.16380    0.0   607.0  245.0  100.0   0.0
# 167  0.716232  44.14680    0.0   637.0  250.0  250.0   0.0
# 168  0.716279  42.62870    0.0   652.0  244.0  500.0   0.0
#
#      threshold_frecuency_high  threshold_frecuency_low      tn     tp
# 0                        0.99                     0.05  1116.0  408.0
# 1                        0.99                     0.05  1040.0  426.0
# 2                        0.99                     0.05   895.0  566.0
# 3                        0.99                     0.05   945.0  535.0
# 4                        0.99                     0.05  1078.0  308.0
# 5                        0.99                     0.05   871.0  571.0
# 6                        0.99                     0.05   814.0  594.0
# 7                        0.99                     0.05   919.0  538.0
# 8                        0.99                     0.05   953.0  509.0
# 9                        0.99                     0.05  1153.0  284.0
# 10                       0.99                     0.05  1057.0  444.0
# 11                       0.99                     0.05  1032.0  411.0
# 12                       0.99                     0.05  1165.0  212.0
# 13                       0.99                     0.05   911.0  672.0
# 14                       0.99                     0.05  1048.0  387.0
# 15                       0.99                     0.05   768.0  692.0
# 16                       0.99                     0.05   865.0  701.0
# 17                       0.99                     0.05   839.0  704.0
# 18                       0.99                     0.05   969.0  630.0
# 19                       0.99                     0.05  1090.0  411.0
# 20                       0.99                     0.05  1076.0  466.0
# 21                       0.99                     0.05   926.0  662.0
# 22                       0.99                     0.05  1033.0  530.0
# 23                       0.99                     0.05  1024.0  554.0
# 24                       0.99                     0.05  1062.0  496.0
# 25                       0.99                     0.05  1128.0  353.0
# 26                       0.99                     0.05  1046.0  404.0
# 27                       0.99                     0.05   833.0  675.0
# 28                       0.99                     0.05   866.0  648.0
# 29                       0.99                     0.05   849.0  661.0
# ..                        ...                      ...     ...    ...
# 139                      0.99                     0.05   970.0  645.0
# 140                      0.99                     0.05   986.0  616.0
# 141                      0.99                     0.05   980.0  612.0
# 142                      0.99                     0.05   988.0  594.0
# 143                      0.99                     0.05   814.0  692.0
# 144                      0.99                     0.05  1080.0  407.0
# 145                      0.99                     0.05   871.0  706.0
# 146                      0.99                     0.05   911.0  707.0
# 147                      0.99                     0.05   915.0  714.0
# 148                      0.99                     0.05   934.0  702.0
# 149                      0.99                     0.05  1031.0  596.0
# 150                      0.99                     0.05  1012.0  625.0
# 151                      0.99                     0.05   950.0  679.0
# 152                      0.99                     0.05  1049.0  629.0
# 153                      0.99                     0.05  1030.0  613.0
# 154                      0.99                     0.05  1054.0  586.0
# 155                      0.99                     0.05  1055.0  572.0
# 156                      0.99                     0.05   769.0  713.0
# 157                      0.99                     0.05  1021.0  452.0
# 158                      0.99                     0.05   836.0  739.0
# 159                      0.99                     0.05   864.0  750.0
# 160                      0.99                     0.05   887.0  755.0
# 161                      0.99                     0.05   887.0  758.0
# 162                      0.99                     0.05   962.0  643.0
# 163                      0.99                     0.05   922.0  744.0
# 164                      0.99                     0.05   976.0  669.0
# 165                      0.99                     0.05   979.0  674.0
# 166                      0.99                     0.05   987.0  661.0
# 167                      0.99                     0.05   982.0  631.0
# 168                      0.99                     0.05   988.0  616.0
#
# [169 rows x 15 columns]

# %%
res_6.to_csv('KNN_TrainTestSize_and_K.csv')
