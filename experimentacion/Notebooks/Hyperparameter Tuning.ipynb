# %%
import pandas as pd
import numpy as np
import subprocess
from itertools import chain, product

# %%
PARAMS_TO_FLAGS = {
    'dataset': '-i',
    'output_file': '-o',
    'mode': '-m',
    'k': '-k',
    'alpha': '-a',
    'threshold_frecuency_low': '-f_low',
    'threshold_frecuency_high': '-f_high',
}

def build_grid(ranges):
    """Build grid based on ranges."""
    def as_list(elmt):
        """Convert elmt to list if elmt is not list."""
        if isinstance(elmt, list):
            return elmt
        else:
            return [elmt]

    grid = product(*(as_list(i) for i in ranges.values()))
    for p in grid:
        yield (dict(zip(ranges.keys(), p)))

# %%
grid_ranges = {
    'dataset': ['../data/train_test_sample_1000.csv'],
    'output_file': ['../../datos/out.csv'], # Todavia no hace nada
    'mode': [0, 1],
    'k': [1, 2, 3, 4, 5, 10, 20, 30, 50],
    'alpha': [0, 1, 5, 10, 15, 20, 25, 30, 50],
    'threshold_frecuency_low': [0.01],
    'threshold_frecuency_high': [0.99],
}

# Un generator(iterador) de los puntos de la grilla
grid = list(build_grid(ranges=grid_ranges))
print(grid[0])
print(grid[1])
print(grid[2])
# Out:
# {'dataset': '../data/train_test_sample_1000.csv', 'output_file': '../../datos/out.csv', 'mode': 0, 'k': 1, 'alpha': 0, 'threshold_frecuency_low': 0.01, 'threshold_frecuency_high': 0.99}
# {'dataset': '../data/train_test_sample_1000.csv', 'output_file': '../../datos/out.csv', 'mode': 0, 'k': 1, 'alpha': 1, 'threshold_frecuency_low': 0.01, 'threshold_frecuency_high': 0.99}
# {'dataset': '../data/train_test_sample_1000.csv', 'output_file': '../../datos/out.csv', 'mode': 0, 'k': 1, 'alpha': 5, 'threshold_frecuency_low': 0.01, 'threshold_frecuency_high': 0.99}

# %%
def parse_results(output, niters):
    N, time, eigen_val, *eigen_vec = list(map(float, output.decode().split('\n')[:-1]))
    return {
        'N': N,
        'time': time,
        'niters': niters,
        'eigen_val': eigen_val,
        'eigen_vec': np.array(eigen_vec),
    }


def output_to_dict(output):
    # Parsear la salida a un diccionario
    lines = output.decode().split('\n')
    d = dict(tuple(l.split(': ')) for l in lines if ': ' in l)
    for k, v in d.items():
        if k != 'Dataset File':
            d[k] = float(v)
    return d

def run(exc_path, params):
    args = tuple(chain(*((PARAMS_TO_FLAGS[p], str(v)) for p, v in params.items())))
    args = [exc_path, *args]
    output = subprocess.check_output(args)
    return output_to_dict(output)

# %%
EXEC_PATH = '../executables/tp2'
param_set = {
    'dataset': '../data/train_test_sample_1000.csv', 
    'output_file': '../../datos/out.csv', 
    'mode': 0, 
    'k': 1, 
    'alpha': 0, 
    'threshold_frecuency_low': 0.01, 
    'threshold_frecuency_high': 0.99
}
out = run(EXEC_PATH, param_set)
out
# Out:
# {'Dataset File': '../data/train_test_sample_1000.csv',
#  'mode': 0.0,
#  'k': 1.0,
#  'alpha': 0.0,
#  'threshold_frecuency_low': 0.01,
#  'threshold_frecuency_high': 0.99,
#  'tp': 557.0,
#  'fp': 400.0,
#  'tn': 837.0,
#  'fn': 706.0,
#  'Accuracy': 0.5576,
#  'Precision': 0.441013,
#  'Recall': 0.582027,
#  'F1': 0.501802,
#  'Time': 4.43996}

# %%
# Correrlo para una grilla chica para ver que pasa con los thresholds
grid_ranges = {
    'dataset': ['../data/train_test_sample_1000.csv'],
    'output_file': ['../../datos/out.csv'], # Todavia no hace nada
    'mode': [0],
    'k': [5],
    'alpha': [0],
    'threshold_frecuency_low': [0.01, 0.05, 0.1, 0.15, 0.2, 0.25],
    'threshold_frecuency_high': [0.8, 0.85, 0.9, 0.95, 0.99],
}
results = []
grid = list(build_grid(grid_ranges))
for i, point in enumerate(grid):
    print('\r', f'Running for point {i+1}/{len(grid)}', end='         ')
    out = run(EXEC_PATH, point)
    results.append(out)
results_df = pd.DataFrame(results)
# Out:
#  Running for point 30/30

# %%
results_df.head()
# Out:
#    Accuracy                        Dataset File        F1  Precision  \
# 0    0.5740  ../data/train_test_sample_1000.csv  0.492616   0.409343
# 1    0.5704  ../data/train_test_sample_1000.csv  0.487595   0.404592
# 2    0.5692  ../data/train_test_sample_1000.csv  0.488361   0.406968
# 3    0.5700  ../data/train_test_sample_1000.csv  0.477902   0.389549
# 4    0.5816  ../data/train_test_sample_1000.csv  0.503795   0.420428
#
#      Recall     Time  alpha     fn     fp    k  mode  \
# 0  0.618421  4.41691    0.0  746.0  319.0  5.0   0.0
# 1  0.613445  4.42123    0.0  752.0  322.0  5.0   0.0
# 2  0.610451  4.41246    0.0  749.0  328.0  5.0   0.0
# 3  0.618090  4.38617    0.0  771.0  304.0  5.0   0.0
# 4  0.628402  4.37539    0.0  732.0  314.0  5.0   0.0
#
#    threshold_frecuency_high  threshold_frecuency_low     tn     tp
# 0                      0.80                     0.01  918.0  517.0
# 1                      0.85                     0.01  915.0  511.0
# 2                      0.90                     0.01  909.0  514.0
# 3                      0.95                     0.01  933.0  492.0
# 4                      0.99                     0.01  923.0  531.0

# %%
# results_df.sort_values('Accuracy')

# %%
# pareceria ser que los valores de los thresholds en 0.2 y 0.95 son los mejores.
# Igual es un conjunto de datos bastante chico habria que probar con mas datos

# %%
import sys
from multiprocessing import Pool

def run_grid_in_parallel(grid, n_proc=18):
    """Run a grid on n_proc workers"""
    done, results = 0, []
    
    def call_back(out):
        nonlocal done
        nonlocal results
        results.append(out)
        done += 1
        print('\r', f'Point {done}/{len(grid)} done', end='         ')
        sys.stdout.flush()

    with Pool(n_proc) as pool:
        for point in grid:
            pool.apply_async(run, args=(EXEC_PATH, point, ), callback=call_back)
        pool.close()
        pool.join()
    return pd.DataFrame(results)

grid_ranges = {
    'dataset': ['../data/train_test_sample_1000.csv'],
    'output_file': ['../../datos/out.csv'], # Todavia no hace nada
    'mode': [0],
    'k': [5],
    'alpha': [0],
    'threshold_frecuency_low': [0.01, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.4, 0.5],
    'threshold_frecuency_high': [0.7, 0.75, 0.8, 0.85, 0.9, 0.95, 0.99],
}
grid = list(build_grid(grid_ranges))
res = run_grid_in_parallel(grid)
# Out:
#  Point 63/63 done

# %%
res.sort_values('Accuracy', ascending=False).head()
# Out:
#     Accuracy                        Dataset File        F1  Precision  \
# 8     0.6104  ../data/train_test_sample_1000.csv  0.592469   0.555294
# 4     0.6056  ../data/train_test_sample_1000.csv  0.590191   0.556863
# 5     0.6040  ../data/train_test_sample_1000.csv  0.594262   0.568627
# 14    0.6040  ../data/train_test_sample_1000.csv  0.594262   0.568627
# 1     0.6020  ../data/train_test_sample_1000.csv  0.587308   0.555294
#
#       Recall     Time  alpha     fn     fp    k  mode  \
# 8   0.634978  2.26049    0.0  567.0  407.0  5.0   0.0
# 4   0.627763  2.20125    0.0  565.0  421.0  5.0   0.0
# 5   0.622318  2.21171    0.0  550.0  440.0  5.0   0.0
# 14  0.622318  1.06052    0.0  550.0  440.0  5.0   0.0
# 1   0.623239  1.04956    0.0  567.0  428.0  5.0   0.0
#
#     threshold_frecuency_high  threshold_frecuency_low     tn     tp
# 8                       0.70                     0.05  818.0  708.0
# 4                       0.75                     0.05  804.0  710.0
# 5                       0.99                     0.05  785.0  725.0
# 14                      0.99                     0.10  785.0  725.0
# 1                       0.70                     0.10  797.0  708.0

# %%
def score_metrics(scores, metrics=['Accuracy', 'F1','Precision', 'Recall'], top=5):
    for metric in metrics:
        for t in range(top):
            scores.sort_values(metric, ascending=False).iloc[t]

# %%
import sys
from multiprocessing import Pool

def run_grid_in_parallel(grid, n_proc=18):
    """Run a grid on n_proc workers"""
    done, results = 0, []
    
    def call_back(out):
        nonlocal done
        nonlocal results
        results.append(out)
        done += 1
        print('\r', f'Point {done}/{len(grid)} done', end='         ')
        sys.stdout.flush()

    with Pool(n_proc) as pool:
        for point in grid:
            pool.apply_async(run, args=(EXEC_PATH, point, ), callback=call_back)
        pool.close()
        pool.join()
    return pd.DataFrame(results)

grid_ranges = {
    'dataset': ['../data/train_test_sample_1000.csv'],
    'output_file': ['../../datos/out.csv'], # Todavia no hace nada
    'mode': [1],
    'k': [1, 2, 3, 5, 7, 9, 10, 15, 20],
    'alpha': [25, 50, 75, 100, 150],
    'threshold_frecuency_low': [0.05],
    'threshold_frecuency_high': [0.99],
}
grid = list(build_grid(grid_ranges))
res_2 = run_grid_in_parallel(grid)
# Out:
#  Point 45/45 done

# %%
res_2.sort_values('Precision', ascending=False)
# Out:
#     Accuracy                        Dataset File        F1  Precision  \
# 11    0.5700  ../data/train_test_sample_1000.csv  0.539615   0.498812
# 0     0.5464  ../data/train_test_sample_1000.csv  0.524329   0.494854
# 7     0.5680  ../data/train_test_sample_1000.csv  0.534884   0.491686
# 15    0.5652  ../data/train_test_sample_1000.csv  0.530859   0.486936
# 4     0.5584  ../data/train_test_sample_1000.csv  0.526587   0.486144
# 8     0.5800  ../data/train_test_sample_1000.csv  0.535398   0.479018
# 3     0.5732  ../data/train_test_sample_1000.csv  0.530163   0.476643
# 10    0.5904  ../data/train_test_sample_1000.csv  0.537906   0.471892
# 12    0.5708  ../data/train_test_sample_1000.csv  0.524169   0.467933
# 1     0.5516  ../data/train_test_sample_1000.csv  0.513244   0.467933
# 2     0.5604  ../data/train_test_sample_1000.csv  0.516498   0.464766
# 28    0.5908  ../data/train_test_sample_1000.csv  0.532663   0.461599
# 17    0.5732  ../data/train_test_sample_1000.csv  0.522167   0.461599
# 29    0.6012  ../data/train_test_sample_1000.csv  0.538212   0.460016
# 21    0.5880  ../data/train_test_sample_1000.csv  0.530109   0.460016
# 26    0.5960  ../data/train_test_sample_1000.csv  0.533272   0.456849
# 25    0.5912  ../data/train_test_sample_1000.csv  0.529032   0.454473
# 23    0.5880  ../data/train_test_sample_1000.csv  0.526219   0.452890
# 31    0.5944  ../data/train_test_sample_1000.csv  0.529248   0.451306
# 20    0.5728  ../data/train_test_sample_1000.csv  0.515426   0.449723
# 18    0.5628  ../data/train_test_sample_1000.csv  0.509205   0.448931
# 5     0.5704  ../data/train_test_sample_1000.csv  0.512704   0.447348
# 34    0.5936  ../data/train_test_sample_1000.csv  0.525234   0.444972
# 40    0.5984  ../data/train_test_sample_1000.csv  0.524171   0.437846
# 30    0.5876  ../data/train_test_sample_1000.csv  0.516643   0.436263
# 37    0.6004  ../data/train_test_sample_1000.csv  0.524059   0.435471
# 24    0.5772  ../data/train_test_sample_1000.csv  0.506305   0.429137
# 19    0.5676  ../data/train_test_sample_1000.csv  0.499769   0.427553
# 42    0.5896  ../data/train_test_sample_1000.csv  0.511429   0.425178
# 36    0.5944  ../data/train_test_sample_1000.csv  0.512500   0.422011
# 38    0.5836  ../data/train_test_sample_1000.csv  0.471305   0.367379
# 44    0.5936  ../data/train_test_sample_1000.csv  0.473029   0.361045
# 41    0.5868  ../data/train_test_sample_1000.csv  0.465044   0.355503
# 43    0.5884  ../data/train_test_sample_1000.csv  0.464341   0.353127
# 39    0.5876  ../data/train_test_sample_1000.csv  0.462180   0.350752
# 33    0.5812  ../data/train_test_sample_1000.csv  0.450394   0.339667
# 32    0.5780  ../data/train_test_sample_1000.csv  0.445029   0.334917
# 22    0.5564  ../data/train_test_sample_1000.csv  0.432156   0.334125
# 27    0.5732  ../data/train_test_sample_1000.csv  0.440482   0.332542
# 35    0.5720  ../data/train_test_sample_1000.csv  0.436842   0.328583
# 14    0.5648  ../data/train_test_sample_1000.csv  0.390135   0.275534
# 35  0.651491  10.00290  150.0  848.0  222.0  10.0   1.0
# 14  0.667946  10.03660   75.0  915.0  173.0   2.0   1.0
# 13  0.672619   9.95007  100.0  924.0  165.0   2.0   1.0
# 9   0.645472   9.84459   50.0  928.0  184.0   2.0   1.0
# 6   0.609615   9.80267   25.0  946.0  203.0   2.0   1.0
# 16  0.644628  10.11470  150.0  951.0  172.0   2.0   1.0
#
#     threshold_frecuency_high  threshold_frecuency_low      tn     tp
# 11                      0.99                     0.05   795.0  630.0
# 0                       0.99                     0.05   741.0  625.0
# 7                       0.99                     0.05   799.0  621.0
# 15                      0.99                     0.05   798.0  615.0
# 4                       0.99                     0.05   782.0  614.0
# 8                       0.99                     0.05   845.0  605.0
# 3                       0.99                     0.05   831.0  602.0
# 10                      0.99                     0.05   880.0  596.0
# 12                      0.99                     0.05   836.0  591.0
# 1                       0.99                     0.05   788.0  591.0
# 2                       0.99                     0.05   814.0  587.0
# 28                      0.99                     0.05   894.0  583.0
# 17                      0.99                     0.05   850.0  583.0
# 29                      0.99                     0.05   922.0  581.0
# 21                      0.99                     0.05   889.0  581.0
# 26                      0.99                     0.05   913.0  577.0
# 25                      0.99                     0.05   904.0  574.0
# 23                      0.99                     0.05   898.0  572.0
# 31                      0.99                     0.05   916.0  570.0
# 20                      0.99                     0.05   864.0  568.0
# 18                      0.99                     0.05   840.0  567.0
# 5                       0.99                     0.05   861.0  565.0
# 34                      0.99                     0.05   922.0  562.0
# 40                      0.99                     0.05   943.0  553.0
# 30                      0.99                     0.05   918.0  551.0
# 37                      0.99                     0.05   951.0  550.0
# 24                      0.99                     0.05   901.0  542.0
# 19                      0.99                     0.05   879.0  540.0
# 42                      0.99                     0.05   937.0  537.0
# 36                      0.99                     0.05   953.0  533.0
# 38                      0.99                     0.05   995.0  464.0
# 44                      0.99                     0.05  1028.0  456.0
# 41                      0.99                     0.05  1018.0  449.0
# 43                      0.99                     0.05  1025.0  446.0
# 39                      0.99                     0.05  1026.0  443.0
# 33                      0.99                     0.05  1024.0  429.0
# 32                      0.99                     0.05  1022.0  423.0
# 22                      0.99                     0.05   969.0  422.0
# 27                      0.99                     0.05  1013.0  420.0
# 35                      0.99                     0.05  1015.0  415.0
# 14                      0.99                     0.05  1064.0  348.0
# 13                      0.99                     0.05  1072.0  339.0
# 9                       0.99                     0.05  1053.0  335.0
# 6                       0.99                     0.05  1034.0  317.0
# 16                      0.99                     0.05  1065.0  312.0

# %%
#Experimentamos variando el tamaño del train test
#KNN + PCA
import sys
from multiprocessing import Pool

def run_grid_in_parallel(grid, n_proc=18):
    """Run a grid on n_proc workers"""
    done, results = 0, []
    
    def call_back(out):
        nonlocal done
        nonlocal results
        results.append(out)
        done += 1
        print('\r', f'Point {done}/{len(grid)} done', end='         ')
        sys.stdout.flush()

    with Pool(n_proc) as pool:
        for point in grid:
            pool.apply_async(run, args=(EXEC_PATH, point, ), callback=call_back)
        pool.close()
        pool.join()
    return pd.DataFrame(results)

file_names = ['../data/train_test_sample_' + str(i) + '.csv' for i in range(1000,25001,1000)]
grid_ranges = {
    'dataset': file_names,
    'output_file': ['../../datos/out.csv'], # Todavia no hace nada
    'mode': [1],
    'k': [15],
    'alpha': [50],
    'threshold_frecuency_low': [0.05],
    'threshold_frecuency_high': [0.99],
}
grid = list(build_grid(grid_ranges))
res_3 = run_grid_in_parallel(grid)
# Out:
#  Point 25/25 done

# %%
res_3
# Out:
#     Accuracy                         Dataset File        F1  Precision  \
# 0     0.5944   ../data/train_test_sample_1000.csv  0.512500   0.422011
# 1     0.6156   ../data/train_test_sample_2000.csv  0.549883   0.468850
# 2     0.6344   ../data/train_test_sample_3000.csv  0.579190   0.505627
# 3     0.6344   ../data/train_test_sample_4000.csv  0.591234   0.546281
# 4     0.6232   ../data/train_test_sample_5000.csv  0.590791   0.544872
# 5     0.6364   ../data/train_test_sample_6000.csv  0.603230   0.541536
# 6     0.6548   ../data/train_test_sample_7000.csv  0.636019   0.583140
# 7     0.6340   ../data/train_test_sample_8000.csv  0.606113   0.583264
# 8     0.6444   ../data/train_test_sample_9000.csv  0.617634   0.582792
# 9     0.6272  ../data/train_test_sample_10000.csv  0.602050   0.555118
# 10    0.6424  ../data/train_test_sample_11000.csv  0.624685   0.599034
# 11    0.6640  ../data/train_test_sample_12000.csv  0.640411   0.604689
# 12    0.6508  ../data/train_test_sample_13000.csv  0.631801   0.605497
# 13    0.6584  ../data/train_test_sample_14000.csv  0.637829   0.593060
# 14    0.6420  ../data/train_test_sample_15000.csv  0.620923   0.581746
# 15    0.6432  ../data/train_test_sample_16000.csv  0.630489   0.610265
# 16    0.6320  ../data/train_test_sample_17000.csv  0.607173   0.560726
# 17    0.6504  ../data/train_test_sample_18000.csv  0.624248   0.576648
# 18    0.6412  ../data/train_test_sample_19000.csv  0.614856   0.573259
# 19    0.6640  ../data/train_test_sample_20000.csv  0.652318   0.609435
# 20    0.6572  ../data/train_test_sample_21000.csv  0.638549   0.598419
# 21    0.6408  ../data/train_test_sample_22000.csv  0.627695   0.593725
# 22    0.6624  ../data/train_test_sample_23000.csv  0.632724   0.595902
# 23    0.6560  ../data/train_test_sample_24000.csv  0.632792   0.599515
# 24    0.6764  ../data/train_test_sample_25000.csv  0.661931   0.624606
#
#       Recall      Time  alpha     fn     fp     k  mode  \
# 0   0.652387   9.78971   50.0  730.0  284.0  15.0   1.0
# 1   0.664779  11.28900   50.0  665.0  296.0  15.0   1.0
# 2   0.677802  13.22350   50.0  615.0  299.0  15.0   1.0
# 3   0.644250  15.12680   50.0  549.0  365.0  15.0   1.0
# 4   0.645161  16.55210   50.0  568.0  374.0  15.0   1.0
# 5   0.680788  18.19010   50.0  585.0  324.0  15.0   1.0
# 6   0.699443  19.40850   50.0  539.0  324.0  15.0   1.0
# 7   0.630824  20.79220   50.0  503.0  412.0  15.0   1.0
# 8   0.656908  21.73680   50.0  514.0  375.0  15.0   1.0
# 9   0.657649  22.86240   50.0  565.0  367.0  15.0   1.0
# 10  0.652632  24.13070   50.0  498.0  396.0  15.0   1.0
# 11  0.680619  25.13650   50.0  489.0  351.0  15.0   1.0
# 12  0.660494  26.47520   50.0  488.0  385.0  15.0   1.0
# 13  0.689908  27.39060   50.0  516.0  338.0  15.0   1.0
# 14  0.665758  28.19740   50.0  527.0  368.0  15.0   1.0
# 15  0.652099  29.42430   50.0  486.0  406.0  15.0   1.0
# 16  0.662011  30.14050   50.0  557.0  363.0  15.0   1.0
# 17  0.680412  30.84100   50.0  533.0  341.0  15.0   1.0
# 18  0.662963  29.53800   50.0  533.0  364.0  15.0   1.0
# 19  0.701692  30.31880   50.0  505.0  335.0  15.0   1.0
# 20  0.684448  31.34860   50.0  508.0  349.0  15.0   1.0
# 21  0.665787  32.14010   50.0  518.0  380.0  15.0   1.0
# 22  0.674397  32.79930   50.0  493.0  351.0  15.0   1.0
# 23  0.669982  32.85980   50.0  495.0  365.0  15.0   1.0
# 24  0.704000  33.08070   50.0  476.0  333.0  15.0   1.0
#
#     threshold_frecuency_high  threshold_frecuency_low     tn     tp
# 0                       0.99                     0.05  953.0  533.0
# 1                       0.99                     0.05  952.0  587.0
# 2                       0.99                     0.05  957.0  629.0
# 3                       0.99                     0.05  925.0  661.0
# 4                       0.99                     0.05  878.0  680.0
# 5                       0.99                     0.05  900.0  691.0
# 6                       0.99                     0.05  883.0  754.0
# 7                       0.99                     0.05  881.0  704.0
# 8                       0.99                     0.05  893.0  718.0
# 9                       0.99                     0.05  863.0  705.0
# 10                      0.99                     0.05  862.0  744.0
# 11                      0.99                     0.05  912.0  748.0
# 12                      0.99                     0.05  878.0  749.0
# 13                      0.99                     0.05  894.0  752.0
# 14                      0.99                     0.05  872.0  733.0
# 15                      0.99                     0.05  847.0  761.0
# 16                      0.99                     0.05  869.0  711.0
# 17                      0.99                     0.05  900.0  726.0
# 18                      0.99                     0.05  887.0  716.0
# 19                      0.99                     0.05  872.0  788.0
# 20                      0.99                     0.05  886.0  757.0
# 21                      0.99                     0.05  845.0  757.0
# 22                      0.99                     0.05  929.0  727.0
# 23                      0.99                     0.05  899.0  741.0
# 24                      0.99                     0.05  899.0  792.0

# %%
res_3.to_csv('KNN_PCA_TrainTestSize.csv')

# %%
#Experimentamos variando el tamaño del train test
#KNN
import sys
from multiprocessing import Pool

def run_grid_in_parallel(grid, n_proc=18):
    """Run a grid on n_proc workers"""
    done, results = 0, []
    
    def call_back(out):
        nonlocal done
        nonlocal results
        results.append(out)
        done += 1
        print('\r', f'Point {done}/{len(grid)} done', end='         ')
        sys.stdout.flush()

    with Pool(n_proc) as pool:
        for point in grid:
            pool.apply_async(run, args=(EXEC_PATH, point, ), callback=call_back)
        pool.close()
        pool.join()
    return pd.DataFrame(results)

file_names = ['../data/train_test_sample_' + str(i) + '.csv' for i in range(1000,25001,1000)]
grid_ranges = {
    'dataset': file_names,
    'output_file': ['../../datos/out.csv'], # Todavia no hace nada
    'mode': [0],
    'k': [15],
    'alpha': [0],
    'threshold_frecuency_low': [0.05],
    'threshold_frecuency_high': [0.99],
}
grid = list(build_grid(grid_ranges))
res_4 = run_grid_in_parallel(grid)
# Out:
#  Point 25/25 done

# %%
res_4
# Out:
#     Accuracy                         Dataset File        F1  Precision  \
# 0     0.5848   ../data/train_test_sample_1000.csv  0.495136   0.403009
# 1     0.6052   ../data/train_test_sample_2000.csv  0.511144   0.412141
# 2     0.6396   ../data/train_test_sample_3000.csv  0.583063   0.506431
# 3     0.6356   ../data/train_test_sample_4000.csv  0.574895   0.509091
# 4     0.6312   ../data/train_test_sample_5000.csv  0.588393   0.528045
# 5     0.6112   ../data/train_test_sample_6000.csv  0.586383   0.539969
# 6     0.6480   ../data/train_test_sample_7000.csv  0.626486   0.570766
# 7     0.6440   ../data/train_test_sample_8000.csv  0.607237   0.570008
# 8     0.6412   ../data/train_test_sample_9000.csv  0.624529   0.605519
# 9     0.6296  ../data/train_test_sample_10000.csv  0.603935   0.555906
# 10    0.6456  ../data/train_test_sample_11000.csv  0.613775   0.566828
# 11    0.6464  ../data/train_test_sample_12000.csv  0.612281   0.564268
# 12    0.6432  ../data/train_test_sample_13000.csv  0.620102   0.588521
# 13    0.6636  ../data/train_test_sample_14000.csv  0.639211   0.587539
# 14    0.6452  ../data/train_test_sample_15000.csv  0.616515   0.565873
# 15    0.6380  ../data/train_test_sample_16000.csv  0.613083   0.574980
# 16    0.6256  ../data/train_test_sample_17000.csv  0.586207   0.522871
# 15                      0.99                     0.05  878.0  717.0
# 16                      0.99                     0.05  901.0  663.0
# 17                      0.99                     0.05  953.0  690.0
# 18                      0.99                     0.05  939.0  692.0
# 19                      0.99                     0.05  909.0  750.0
# 20                      0.99                     0.05  900.0  699.0
# 21                      0.99                     0.05  914.0  705.0
# 22                      0.99                     0.05  950.0  679.0
# 23                      0.99                     0.05  941.0  708.0
# 24                      0.99                     0.05  922.0  744.0

# %%
res_4.to_csv('KNN_TrainTestSize.csv')

# %%
#Como se relaciona k con el tamaño del training set

# %%
#Experimentamos variando el tamaño del train test y k
#KNN + PCA

import sys
from multiprocessing import Pool

def run_grid_in_parallel(grid, n_proc=18):
    """Run a grid on n_proc workers"""
    done, results = 0, []
    
    def call_back(out):
        nonlocal done
        nonlocal results
        results.append(out)
        done += 1
        print('\r', f'Point {done}/{len(grid)} done', end='         ')
        sys.stdout.flush()

    with Pool(n_proc) as pool:
        for point in grid:
            pool.apply_async(run, args=(EXEC_PATH, point, ), callback=call_back)
        pool.close()
        pool.join()
    return pd.DataFrame(results)

file_names = ['../data/train_test_sample_' + str(i) + '.csv' for i in range(1000,25001,2000)]
grid_ranges = {
    'dataset': file_names,
    'output_file': ['../../datos/out.csv'], # Todavia no hace nada
    'mode': [1],
    'k': [1, 2, 3, 5, 7, 9, 10, 15, 20],
    'alpha': [50],
    'threshold_frecuency_low': [0.05],
    'threshold_frecuency_high': [0.99],
}
grid = list(build_grid(grid_ranges))
res_5 = run_grid_in_parallel(grid)
# Out:
#  Point 117/117 done

# %%
res_5
# Out:
#      Accuracy                         Dataset File        F1  Precision  \
# 0      0.5584   ../data/train_test_sample_1000.csv  0.526587   0.486144
# 1      0.5552   ../data/train_test_sample_1000.csv  0.375982   0.265241
# 2      0.5704   ../data/train_test_sample_1000.csv  0.512704   0.447348
# 3      0.5876   ../data/train_test_sample_1000.csv  0.462180   0.350752
# 4      0.5732   ../data/train_test_sample_1000.csv  0.530163   0.476643
# 5      0.5676   ../data/train_test_sample_1000.csv  0.499769   0.427553
# 6      0.5944   ../data/train_test_sample_1000.csv  0.512500   0.422011
# 7      0.5772   ../data/train_test_sample_1000.csv  0.506305   0.429137
# 8      0.5732   ../data/train_test_sample_1000.csv  0.440482   0.332542
# 9      0.5748   ../data/train_test_sample_3000.csv  0.418172   0.307074
# 10     0.6188   ../data/train_test_sample_3000.csv  0.521826   0.418006
# 11     0.6212   ../data/train_test_sample_3000.csv  0.578924   0.523312
# 12     0.6164   ../data/train_test_sample_3000.csv  0.565473   0.501608
# 13     0.5936   ../data/train_test_sample_3000.csv  0.579818   0.563505
# 14     0.6084   ../data/train_test_sample_3000.csv  0.574163   0.530547
# 15     0.5964   ../data/train_test_sample_3000.csv  0.568988   0.535370
# 16     0.6344   ../data/train_test_sample_3000.csv  0.579190   0.505627
# 17     0.6220   ../data/train_test_sample_3000.csv  0.531947   0.431672
# 18     0.6232   ../data/train_test_sample_5000.csv  0.590791   0.544872
# 19     0.6088   ../data/train_test_sample_5000.csv  0.585593   0.553686
# 20     0.6164   ../data/train_test_sample_5000.csv  0.591741   0.556891
# 21     0.6212   ../data/train_test_sample_5000.csv  0.556855   0.476763
# 22     0.5656   ../data/train_test_sample_5000.csv  0.412338   0.305288
# 23     0.6056   ../data/train_test_sample_5000.csv  0.584317   0.555288
# 24     0.6172   ../data/train_test_sample_5000.csv  0.552595   0.473558
# 25     0.5712   ../data/train_test_sample_5000.csv  0.557756   0.541667
# 26     0.5996   ../data/train_test_sample_5000.csv  0.578526   0.550481
# 27     0.5776   ../data/train_test_sample_7000.csv  0.579952   0.563805
# 28     0.6404   ../data/train_test_sample_7000.csv  0.626506   0.583140
# 29     0.5976   ../data/train_test_sample_7000.csv  0.591721   0.563805
# ..        ...                                  ...       ...        ...
# 87     0.6288  ../data/train_test_sample_19000.csv  0.569972   0.492394
# 88     0.6416  ../data/train_test_sample_19000.csv  0.595303   0.527622
# 89     0.6412  ../data/train_test_sample_19000.csv  0.614856   0.573259
# 90     0.5832  ../data/train_test_sample_21000.csv  0.582866   0.575494
# 91     0.5804  ../data/train_test_sample_21000.csv  0.467783   0.364427
# 92     0.6096  ../data/train_test_sample_21000.csv  0.603896   0.588142
# 93     0.6252  ../data/train_test_sample_21000.csv  0.618019   0.599209
# 94     0.6232  ../data/train_test_sample_21000.csv  0.612026   0.587352
# 95     0.6376  ../data/train_test_sample_21000.csv  0.590786   0.516996
# 96     0.6344  ../data/train_test_sample_21000.csv  0.620747   0.591304
# 97     0.6572  ../data/train_test_sample_21000.csv  0.638549   0.598419
# 98     0.6576  ../data/train_test_sample_21000.csv  0.621908   0.556522
# 99     0.6036  ../data/train_test_sample_23000.csv  0.591003   0.586885
# 100    0.6396  ../data/train_test_sample_23000.csv  0.613802   0.586885
# 101    0.5916  ../data/train_test_sample_23000.csv  0.451959   0.345082
# 102    0.6440  ../data/train_test_sample_23000.csv  0.616379   0.586066
# 103    0.6196  ../data/train_test_sample_23000.csv  0.597886   0.579508
# 104    0.6452  ../data/train_test_sample_23000.csv  0.617837   0.587705
# 105    0.6624  ../data/train_test_sample_23000.csv  0.632724   0.595902
# 106    0.6364  ../data/train_test_sample_23000.csv  0.573440   0.500820
# 107    0.6652  ../data/train_test_sample_23000.csv  0.613752   0.545082
# 108    0.5920  ../data/train_test_sample_25000.csv  0.589041   0.576498
# 109    0.6380  ../data/train_test_sample_25000.csv  0.632263   0.613565
# 110    0.5788  ../data/train_test_sample_25000.csv  0.462481   0.357256
# 111    0.6068  ../data/train_test_sample_25000.csv  0.603149   0.589117
# 112    0.6480  ../data/train_test_sample_25000.csv  0.639344   0.615142
# 113    0.6764  ../data/train_test_sample_25000.csv  0.661931   0.624606
# 114    0.6464  ../data/train_test_sample_25000.csv  0.604651   0.533123
# 115    0.6584  ../data/train_test_sample_25000.csv  0.651997   0.630915
# 116    0.6652  ../data/train_test_sample_25000.csv  0.631115   0.564669
#
#        Recall      Time  alpha     fn     fp     k  mode  \
# 0    0.574369   9.72654   50.0  649.0  455.0   1.0   1.0
# 1    0.645472   9.74003   50.0  928.0  184.0   2.0   1.0
# 2    0.600425   9.76386   50.0  698.0  376.0   5.0   1.0
# 3    0.677370   9.77346   50.0  820.0  211.0  20.0   1.0
# 4    0.597222   9.78166   50.0  661.0  406.0   3.0   1.0
# 5    0.601336   9.76758   50.0  723.0  358.0   7.0   1.0
# 6    0.652387   9.79865   50.0  730.0  284.0  15.0   1.0
# 7    0.617312   9.79892   50.0  721.0  336.0   9.0   1.0
# 8    0.652174   9.82602   50.0  843.0  224.0  10.0   1.0
# 9    0.655232  13.05510   50.0  862.0  201.0   2.0   1.0
# 10   0.694259  13.03510   50.0  724.0  229.0  10.0   1.0
sys
from multiprocessing import Pool

def run_grid_in_parallel(grid, n_proc=18):
    """Run a grid on n_proc workers"""
    done, results = 0, []
    
    def call_back(out):
        nonlocal done
        nonlocal results
        results.append(out)
        done += 1
        print('\r', f'Point {done}/{len(grid)} done', end='         ')
        sys.stdout.flush()

    with Pool(n_proc) as pool:
        for point in grid:
            pool.apply_async(run, args=(EXEC_PATH, point, ), callback=call_back)
        pool.close()
        pool.join()
    return pd.DataFrame(results)

file_names = ['../data/train_test_sample_' + str(i) + '.csv' for i in range(1000,25001,2000)]
grid_ranges = {
    'dataset': file_names,
    'output_file': ['../../datos/out.csv'], # Todavia no hace nada
    'mode': [0],
    'k': [1, 2, 3, 5, 7, 9, 10, 15, 20],
    'alpha': [0],
    'threshold_frecuency_low': [0.05],
    'threshold_frecuency_high': [0.99],
}
grid = list(build_grid(grid_ranges))
res_6 = run_grid_in_parallel(grid)
# Out:
#  Point 117/117 done

# %%
res_6
# Out:
#      Accuracy                         Dataset File        F1  Precision  \
# 0      0.5544   ../data/train_test_sample_1000.csv  0.356069   0.243864
# 1      0.5844   ../data/train_test_sample_1000.csv  0.521419   0.448139
# 2      0.5864   ../data/train_test_sample_1000.csv  0.451750   0.337292
# 3      0.5848   ../data/train_test_sample_1000.csv  0.495136   0.403009
# 4      0.5768   ../data/train_test_sample_1000.csv  0.519091   0.452098
# 5      0.5632   ../data/train_test_sample_1000.csv  0.521053   0.470309
# 6      0.5828   ../data/train_test_sample_1000.csv  0.507787   0.425970
# 7      0.5772   ../data/train_test_sample_1000.csv  0.437467   0.325416
# 8      0.5920   ../data/train_test_sample_1000.csv  0.511962   0.423595
# 9      0.6252   ../data/train_test_sample_3000.csv  0.530796   0.426045
# 10     0.6396   ../data/train_test_sample_3000.csv  0.583063   0.506431
# 11     0.6312   ../data/train_test_sample_3000.csv  0.545813   0.445338
# 12     0.5740   ../data/train_test_sample_3000.csv  0.420881   0.311093
# 13     0.6172   ../data/train_test_sample_3000.csv  0.595349   0.565916
# 14     0.6352   ../data/train_test_sample_3000.csv  0.592129   0.532154
# 15     0.5840   ../data/train_test_sample_3000.csv  0.570957   0.556270
# 16     0.6332   ../data/train_test_sample_3000.csv  0.594427   0.540193
# 17     0.6264   ../data/train_test_sample_3000.csv  0.600171   0.563505
# 18     0.6032   ../data/train_test_sample_5000.csv  0.576430   0.540865
# 19     0.6172   ../data/train_test_sample_5000.csv  0.539683   0.449519
# 20     0.5800   ../data/train_test_sample_5000.csv  0.434876   0.323718
# 21     0.6312   ../data/train_test_sample_5000.csv  0.588393   0.528045
# 22     0.6016   ../data/train_test_sample_5000.csv  0.513672   0.421474
# 23     0.6040   ../data/train_test_sample_5000.csv  0.571799   0.529647
# 24     0.5756   ../data/train_test_sample_5000.csv  0.552132   0.524038
# 25     0.6056   ../data/train_test_sample_5000.csv  0.567923   0.519231
# 26     0.6076   ../data/train_test_sample_5000.csv  0.565352   0.511218
# 27     0.5740   ../data/train_test_sample_7000.csv  0.569000   0.543697
# 28     0.5672   ../data/train_test_sample_7000.csv  0.433508   0.320186
# 29     0.6240   ../data/train_test_sample_7000.csv  0.611570   0.572312
# ..        ...                                  ...       ...        ...
# 87     0.6524  ../data/train_test_sample_19000.csv  0.614292   0.554043
# 88     0.6336  ../data/train_test_sample_19000.csv  0.560038   0.466773
# 89     0.6460  ../data/train_test_sample_19000.csv  0.588181   0.506005
# 90     0.5836  ../data/train_test_sample_21000.csv  0.575967   0.558893
# 91     0.5828  ../data/train_test_sample_21000.csv  0.457618   0.347826
# 92     0.6084  ../data/train_test_sample_21000.csv  0.589862   0.556522
# 93     0.6184  ../data/train_test_sample_21000.csv  0.594732   0.553360
# 94     0.6312  ../data/train_test_sample_21000.csv  0.601900   0.550988
# 95     0.6376  ../data/train_test_sample_21000.csv  0.581717   0.498024
# 96     0.6396  ../data/train_test_sample_21000.csv  0.608090   0.552569
# 97     0.6320  ../data/train_test_sample_21000.csv  0.609839   0.568379
# 98     0.6200  ../data/train_test_sample_21000.csv  0.553991   0.466403
# 99     0.6472  ../data/train_test_sample_23000.csv  0.615854   0.579508
# 100    0.6024  ../data/train_test_sample_23000.csv  0.582002   0.567213
# 101    0.5948  ../data/train_test_sample_23000.csv  0.445539   0.333607
# 102    0.6308  ../data/train_test_sample_23000.csv  0.604711   0.578689
# 103    0.6544  ../data/train_test_sample_23000.csv  0.619048   0.575410
# 104    0.6516  ../data/train_test_sample_23000.csv  0.609242   0.556557
# 105    0.6508  ../data/train_test_sample_23000.csv  0.577240   0.488525
# 106    0.6516  ../data/train_test_sample_23000.csv  0.621140   0.585246
# 107    0.6548  ../data/train_test_sample_23000.csv  0.591576   0.512295
# 108    0.5928  ../data/train_test_sample_25000.csv  0.583470   0.562303
# 109    0.5892  ../data/train_test_sample_25000.csv  0.468151   0.356467
# 110    0.6456  ../data/train_test_sample_25000.csv  0.628667   0.591483
# 111    0.6420  ../data/train_test_sample_25000.csv  0.589638   0.507098
# 112    0.6568  ../data/train_test_sample_25000.csv  0.637669   0.595426
# 113    0.6300  ../data/train_test_sample_25000.csv  0.615065   0.582808
# 114    0.6580  ../data/train_test_sample_25000.csv  0.610123   0.527603
# 115    0.6580  ../data/train_test_sample_25000.csv  0.639393   0.597792
# 116    0.6664  ../data/train_test_sample_25000.csv  0.640827   0.586751
#
#        Recall      Time  alpha     fn     fp     k  mode  \
# 0    0.659529   1.76847    0.0  955.0  159.0   2.0   0.0
# 1    0.623348   1.78442    0.0  697.0  342.0   5.0   0.0
# 2    0.683788   1.81874    0.0  837.0  197.0  20.0   0.0
# 3    0.641866   1.81303    0.0  754.0  284.0  15.0   0.0
# 4    0.609392   1.83160    0.0  692.0  366.0   3.0   0.0
# 5    0.584071   1.85518    0.0  669.0  423.0   1.0   0.0
# 6    0.628505   1.85387    0.0  725.0  318.0   7.0   0.0
# 7    0.667208   1.86743    0.0  852.0  205.0  10.0   0.0
# 8    0.646917   1.88562    0.0  728.0  292.0   9.0   0.0
# 9    0.703851   5.93448    0.0  714.0  223.0  20.0   0.0
# 10   0.687023   5.99479    0.0  614.0  287.0  15.0   0.0
# 11   0.704835   6.02678    0.0  690.0  232.0  10.0   0.0
# 12   0.650420   6.02858    0.0  857.0  208.0   2.0   0.0
# 13   0.628011   6.07473    0.0  540.0  417.0   3.0   0.0
# 14   0.667339   6.09943    0.0  582.0  330.0   9.0   0.0
