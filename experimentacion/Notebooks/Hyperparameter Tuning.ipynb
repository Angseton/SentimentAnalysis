# %%
import pandas as pd
import numpy as np
import subprocess
from itertools import chain, product

# %%
PARAMS_TO_FLAGS = {
    'dataset': '-i',
    'output_file': '-o',
    'mode': '-m',
    'k': '-k',
    'alpha': '-a',
    'threshold_frecuency_low': '-f_low',
    'threshold_frecuency_high': '-f_high',
}

def build_grid(ranges):
    """Build grid based on ranges."""
    def as_list(elmt):
        """Convert elmt to list if elmt is not list."""
        if isinstance(elmt, list):
            return elmt
        else:
            return [elmt]

    grid = product(*(as_list(i) for i in ranges.values()))
    for p in grid:
        yield (dict(zip(ranges.keys(), p)))

# %%
grid_ranges = {
    'dataset': ['../data/train_test_sample_1000.csv'],
    'output_file': ['../../datos/out.csv'], # Todavia no hace nada
    'mode': [0, 1],
    'k': [1, 2, 3, 4, 5, 10, 20, 30, 50],
    'alpha': [0, 1, 5, 10, 15, 20, 25, 30, 50],
    'threshold_frecuency_low': [0.01],
    'threshold_frecuency_high': [0.99],
}

# Un generator(iterador) de los puntos de la grilla
grid = list(build_grid(ranges=grid_ranges))
print(grid[0])
print(grid[1])
print(grid[2])
# Out:
# {'dataset': '../data/train_test_sample_1000.csv', 'output_file': '../../datos/out.csv', 'mode': 0, 'k': 1, 'alpha': 0, 'threshold_frecuency_low': 0.01, 'threshold_frecuency_high': 0.99}
# {'dataset': '../data/train_test_sample_1000.csv', 'output_file': '../../datos/out.csv', 'mode': 0, 'k': 1, 'alpha': 1, 'threshold_frecuency_low': 0.01, 'threshold_frecuency_high': 0.99}
# {'dataset': '../data/train_test_sample_1000.csv', 'output_file': '../../datos/out.csv', 'mode': 0, 'k': 1, 'alpha': 5, 'threshold_frecuency_low': 0.01, 'threshold_frecuency_high': 0.99}

# %%
def parse_results(output, niters):
    N, time, eigen_val, *eigen_vec = list(map(float, output.decode().split('\n')[:-1]))
    return {
        'N': N,
        'time': time,
        'niters': niters,
        'eigen_val': eigen_val,
        'eigen_vec': np.array(eigen_vec),
    }


def output_to_dict(output):
    # Parsear la salida a un diccionario
    lines = output.decode().split('\n')
    d = dict(tuple(l.split(': ')) for l in lines if ': ' in l)
    for k, v in d.items():
        if k != 'Dataset File':
            d[k] = float(v)
    return d

def run(exc_path, params):
    args = tuple(chain(*((PARAMS_TO_FLAGS[p], str(v)) for p, v in params.items())))
    args = [exc_path, *args]
    output = subprocess.check_output(args)
    return output_to_dict(output)

# %%
EXEC_PATH = '../executables/tp2'
param_set = {
    'dataset': '../data/train_test_sample_1000.csv', 
    'output_file': '../../datos/out.csv', 
    'mode': 0, 
    'k': 1, 
    'alpha': 0, 
    'threshold_frecuency_low': 0.01, 
    'threshold_frecuency_high': 0.99
}
out = run(EXEC_PATH, param_set)
out
# Out:
# {'Dataset File': '../data/train_test_sample_1000.csv',
#  'mode': 0.0,
#  'k': 1.0,
#  'alpha': 0.0,
#  'threshold_frecuency_low': 0.01,
#  'threshold_frecuency_high': 0.99,
#  'tp': 327.0,
#  'fp': 228.0,
#  'tn': 537.0,
#  'fn': 408.0,
#  'Accuracy': 0.576,
#  'Precision': 0.444898,
#  'Recall': 0.589189,
#  'F1': 0.506977,
#  'Time': 2.7115}

# %%
# Correrlo para una grilla chica para ver que pasa con los thresholds
grid_ranges = {
    'dataset': ['../data/train_test_sample_1000.csv'],
    'output_file': ['../../datos/out.csv'], # Todavia no hace nada
    'mode': [0],
    'k': [5],
    'alpha': [0],
    'threshold_frecuency_low': [0.01, 0.05, 0.1, 0.15, 0.2, 0.25],
    'threshold_frecuency_high': [0.8, 0.85, 0.9, 0.95, 0.99],
}
results = []
grid = list(build_grid(grid_ranges))
for i, point in enumerate(grid):
    print('\r', f'Running for point {i+1}/{len(grid)}', end='         ')
    out = run(EXEC_PATH, point)
    results.append(out)
results_df = pd.DataFrame(results)
# Out:
#  Running for point 30/30

# %%
results_df.head()
# Out:
#    Accuracy                        Dataset File        F1  Precision  \
# 0    0.5740  ../data/train_test_sample_1000.csv  0.492616   0.409343
# 1    0.5704  ../data/train_test_sample_1000.csv  0.487595   0.404592
# 2    0.5692  ../data/train_test_sample_1000.csv  0.488361   0.406968
# 3    0.5700  ../data/train_test_sample_1000.csv  0.477902   0.389549
# 4    0.5816  ../data/train_test_sample_1000.csv  0.503795   0.420428
#
#      Recall     Time  alpha     fn     fp    k  mode  \
# 0  0.618421  4.41691    0.0  746.0  319.0  5.0   0.0
# 1  0.613445  4.42123    0.0  752.0  322.0  5.0   0.0
# 2  0.610451  4.41246    0.0  749.0  328.0  5.0   0.0
# 3  0.618090  4.38617    0.0  771.0  304.0  5.0   0.0
# 4  0.628402  4.37539    0.0  732.0  314.0  5.0   0.0
#
#    threshold_frecuency_high  threshold_frecuency_low     tn     tp
# 0                      0.80                     0.01  918.0  517.0
# 1                      0.85                     0.01  915.0  511.0
# 2                      0.90                     0.01  909.0  514.0
# 3                      0.95                     0.01  933.0  492.0
# 4                      0.99                     0.01  923.0  531.0

# %%
# results_df.sort_values('Accuracy')

# %%
# pareceria ser que los valores de los thresholds en 0.2 y 0.95 son los mejores.
# Igual es un conjunto de datos bastante chico habria que probar con mas datos

# %%
import sys
from multiprocessing import Pool

def run_grid_in_parallel(grid, n_proc=18):
    """Run a grid on n_proc workers"""
    done, results = 0, []
    
    def call_back(out):
        nonlocal done
        nonlocal results
        results.append(out)
        done += 1
        print('\r', f'Point {done}/{len(grid)} done', end='         ')
        sys.stdout.flush()

    with Pool(n_proc) as pool:
        for point in grid:
            pool.apply_async(run, args=(EXEC_PATH, point, ), callback=call_back)
        pool.close()
        pool.join()
    return pd.DataFrame(results)

grid_ranges = {
    'dataset': ['../data/train_test_sample_1000.csv'],
    'output_file': ['../../datos/out.csv'], # Todavia no hace nada
    'mode': [0],
    'k': [5],
    'alpha': [0],
    'threshold_frecuency_low': [0.01, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.4, 0.5],
    'threshold_frecuency_high': [0.7, 0.75, 0.8, 0.85, 0.9, 0.95, 0.99],
}
grid = list(build_grid(grid_ranges))
res = run_grid_in_parallel(grid)
# Out:
#  Point 63/63 done

# %%
res.sort_values('Accuracy', ascending=False).head()
# Out:
#     Accuracy                        Dataset File        F1  Precision  \
# 30    0.5872  ../data/train_test_sample_1000.csv  0.530055   0.460808
# 13    0.5856  ../data/train_test_sample_1000.csv  0.523020   0.449723
# 20    0.5844  ../data/train_test_sample_1000.csv  0.525354   0.455265
# 8     0.5844  ../data/train_test_sample_1000.csv  0.521419   0.448139
# 59    0.5816  ../data/train_test_sample_1000.csv  0.503795   0.420428
#
#       Recall      Time  alpha     fn     fp    k  mode  \
# 30  0.623794  0.509370    0.0  681.0  351.0  5.0   0.0
# 13  0.624862  0.844421    0.0  695.0  341.0  5.0   0.0
# 20  0.620950  0.679705    0.0  688.0  351.0  5.0   0.0
# 8   0.623348  1.703990    0.0  697.0  342.0  5.0   0.0
# 59  0.628402  6.064110    0.0  732.0  314.0  5.0   0.0
#
#     threshold_frecuency_high  threshold_frecuency_low     tn     tp
# 30                      0.99                     0.20  886.0  582.0
# 13                      0.99                     0.10  896.0  568.0
# 20                      0.99                     0.15  886.0  575.0
# 8                       0.99                     0.05  895.0  566.0
# 59                      0.99                     0.01  923.0  531.0

# %%
def score_metrics(scores, metrics=['Accuracy', 'F1','Precision', 'Recall'], top=5):
    for metric in metrics:
        for t in range(top):
            scores.sort_values(metric, ascending=False).iloc[t]

# %%
import sys
from multiprocessing import Pool

def run_grid_in_parallel(grid, n_proc=18):
    """Run a grid on n_proc workers"""
    done, results = 0, []
    
    def call_back(out):
        nonlocal done
        nonlocal results
        results.append(out)
        done += 1
        print('\r', f'Point {done}/{len(grid)} done', end='         ')
        sys.stdout.flush()

    with Pool(n_proc) as pool:
        for point in grid:
            pool.apply_async(run, args=(EXEC_PATH, point, ), callback=call_back)
        pool.close()
        pool.join()
    return pd.DataFrame(results)

grid_ranges = {
    'dataset': ['../data/train_test_sample_1000.csv'],
    'output_file': ['../../datos/out.csv'], # Todavia no hace nada
    'mode': [1],
    'k': [1, 2, 3, 5, 7, 9, 10, 15, 20],
    'alpha': [25, 50, 75, 100, 150],
    'threshold_frecuency_low': [0.05],
    'threshold_frecuency_high': [0.99],
}
grid = list(build_grid(grid_ranges))
res_2 = run_grid_in_parallel(grid)
# Out:
#  Point 45/45 done

# %%
res_2.sort_values('Precision', ascending=False)
# Out:
#     Accuracy                        Dataset File        F1  Precision  \
# 11    0.5700  ../data/train_test_sample_1000.csv  0.539615   0.498812
# 0     0.5464  ../data/train_test_sample_1000.csv  0.524329   0.494854
# 7     0.5680  ../data/train_test_sample_1000.csv  0.534884   0.491686
# 15    0.5652  ../data/train_test_sample_1000.csv  0.530859   0.486936
# 4     0.5584  ../data/train_test_sample_1000.csv  0.526587   0.486144
# 8     0.5800  ../data/train_test_sample_1000.csv  0.535398   0.479018
# 3     0.5732  ../data/train_test_sample_1000.csv  0.530163   0.476643
# 10    0.5904  ../data/train_test_sample_1000.csv  0.537906   0.471892
# 12    0.5708  ../data/train_test_sample_1000.csv  0.524169   0.467933
# 1     0.5516  ../data/train_test_sample_1000.csv  0.513244   0.467933
# 2     0.5604  ../data/train_test_sample_1000.csv  0.516498   0.464766
# 28    0.5908  ../data/train_test_sample_1000.csv  0.532663   0.461599
# 17    0.5732  ../data/train_test_sample_1000.csv  0.522167   0.461599
# 29    0.6012  ../data/train_test_sample_1000.csv  0.538212   0.460016
# 21    0.5880  ../data/train_test_sample_1000.csv  0.530109   0.460016
# 26    0.5960  ../data/train_test_sample_1000.csv  0.533272   0.456849
# 25    0.5912  ../data/train_test_sample_1000.csv  0.529032   0.454473
# 23    0.5880  ../data/train_test_sample_1000.csv  0.526219   0.452890
# 31    0.5944  ../data/train_test_sample_1000.csv  0.529248   0.451306
# 20    0.5728  ../data/train_test_sample_1000.csv  0.515426   0.449723
# 18    0.5628  ../data/train_test_sample_1000.csv  0.509205   0.448931
# 5     0.5704  ../data/train_test_sample_1000.csv  0.512704   0.447348
# 34    0.5936  ../data/train_test_sample_1000.csv  0.525234   0.444972
# 40    0.5984  ../data/train_test_sample_1000.csv  0.524171   0.437846
# 30    0.5876  ../data/train_test_sample_1000.csv  0.516643   0.436263
# 37    0.6004  ../data/train_test_sample_1000.csv  0.524059   0.435471
# 24    0.5772  ../data/train_test_sample_1000.csv  0.506305   0.429137
# 19    0.5676  ../data/train_test_sample_1000.csv  0.499769   0.427553
# 42    0.5896  ../data/train_test_sample_1000.csv  0.511429   0.425178
# 36    0.5944  ../data/train_test_sample_1000.csv  0.512500   0.422011
# 38    0.5836  ../data/train_test_sample_1000.csv  0.471305   0.367379
# 44    0.5936  ../data/train_test_sample_1000.csv  0.473029   0.361045
# 41    0.5868  ../data/train_test_sample_1000.csv  0.465044   0.355503
# 43    0.5884  ../data/train_test_sample_1000.csv  0.464341   0.353127
# 39    0.5876  ../data/train_test_sample_1000.csv  0.462180   0.350752
# 33    0.5812  ../data/train_test_sample_1000.csv  0.450394   0.339667
# 32    0.5780  ../data/train_test_sample_1000.csv  0.445029   0.334917
# 22    0.5564  ../data/train_test_sample_1000.csv  0.432156   0.334125
# 27    0.5732  ../data/train_test_sample_1000.csv  0.440482   0.332542
# 35    0.5720  ../data/train_test_sample_1000.csv  0.436842   0.328583
# 14    0.5648  ../data/train_test_sample_1000.csv  0.390135   0.275534
# 13    0.5644  ../data/train_test_sample_1000.csv  0.383701   0.268409
# 9     0.5552  ../data/train_test_sample_1000.csv  0.375982   0.265241
# 6     0.5404  ../data/train_test_sample_1000.csv  0.355580   0.250990
# 16  0.644628  10.11470  150.0  951.0  172.0   2.0   1.0
#
#     threshold_frecuency_high  threshold_frecuency_low      tn     tp
# 11                      0.99                     0.05   795.0  630.0
# 0                       0.99                     0.05   741.0  625.0
# 7                       0.99                     0.05   799.0  621.0
# 15                      0.99                     0.05   798.0  615.0
# 4                       0.99                     0.05   782.0  614.0
# 8                       0.99                     0.05   845.0  605.0
# 3                       0.99                     0.05   831.0  602.0
# 10                      0.99                     0.05   880.0  596.0
# 12                      0.99                     0.05   836.0  591.0
# 1                       0.99                     0.05   788.0  591.0
# 2                       0.99                     0.05   814.0  587.0
# 28                      0.99                     0.05   894.0  583.0
# 17                      0.99                     0.05   850.0  583.0
# 29                      0.99                     0.05   922.0  581.0
# 21                      0.99                     0.05   889.0  581.0
# 26                      0.99                     0.05   913.0  577.0
# 25                      0.99                     0.05   904.0  574.0
# 23                      0.99                     0.05   898.0  572.0
# 31                      0.99                     0.05   916.0  570.0
# 20                      0.99                     0.05   864.0  568.0
# 18                      0.99                     0.05   840.0  567.0
# 5                       0.99                     0.05   861.0  565.0
# 34                      0.99                     0.05   922.0  562.0
# 40                      0.99                     0.05   943.0  553.0
# 30                      0.99                     0.05   918.0  551.0
# 37                      0.99                     0.05   951.0  550.0
# 24                      0.99                     0.05   901.0  542.0
# 19                      0.99                     0.05   879.0  540.0
# 42                      0.99                     0.05   937.0  537.0
# 36                      0.99                     0.05   953.0  533.0
# 38                      0.99                     0.05   995.0  464.0
# 44                      0.99                     0.05  1028.0  456.0
# 41                      0.99                     0.05  1018.0  449.0
# 43                      0.99                     0.05  1025.0  446.0
# 39                      0.99                     0.05  1026.0  443.0
# 33                      0.99                     0.05  1024.0  429.0
# 32                      0.99                     0.05  1022.0  423.0
# 22                      0.99                     0.05   969.0  422.0
# 27                      0.99                     0.05  1013.0  420.0
# 35                      0.99                     0.05  1015.0  415.0
# 14                      0.99                     0.05  1064.0  348.0
# 13                      0.99                     0.05  1072.0  339.0
# 9                       0.99                     0.05  1053.0  335.0
# 6                       0.99                     0.05  1034.0  317.0
# 16                      0.99                     0.05  1065.0  312.0

# %%
#Experimentamos variando el tamaño del train test
#KNN + PCA
import sys
from multiprocessing import Pool

def run_grid_in_parallel(grid, n_proc=18):
    """Run a grid on n_proc workers"""
    done, results = 0, []
    
    def call_back(out):
        nonlocal done
        nonlocal results
        results.append(out)
        done += 1
        print('\r', f'Point {done}/{len(grid)} done', end='         ')
        sys.stdout.flush()

    with Pool(n_proc) as pool:
        for point in grid:
            pool.apply_async(run, args=(EXEC_PATH, point, ), callback=call_back)
        pool.close()
        pool.join()
    return pd.DataFrame(results)

file_names = ['../data/train_test_sample_' + str(i) + '.csv' for i in range(1000,25001,1000)]
grid_ranges = {
    'dataset': file_names,
    'output_file': ['../../datos/out.csv'], # Todavia no hace nada
    'mode': [1],
    'k': [15],
    'alpha': [50],
    'threshold_frecuency_low': [0.05],
    'threshold_frecuency_high': [0.1],
}
grid = list(build_grid(grid_ranges))
res_3 = run_grid_in_parallel(grid)
# Out:
#  Point 25/25 done

# %%
res_3
# Out:
#     Accuracy                         Dataset File        F1  Precision  \
# 0   0.636643   ../data/train_test_sample_1000.csv  0.651912   0.679557
# 1   0.654447   ../data/train_test_sample_2000.csv  0.656944   0.660314
# 2   0.648932   ../data/train_test_sample_3000.csv  0.665437   0.700040
# 3   0.678614   ../data/train_test_sample_4000.csv  0.691287   0.716602
# 4   0.670516   ../data/train_test_sample_5000.csv  0.669700   0.666223
# 5   0.672807   ../data/train_test_sample_6000.csv  0.663370   0.652438
# 6   0.675613   ../data/train_test_sample_7000.csv  0.678148   0.683536
# 7   0.681885   ../data/train_test_sample_8000.csv  0.674720   0.661891
# 8   0.683972   ../data/train_test_sample_9000.csv  0.687516   0.694204
# 9   0.672762  ../data/train_test_sample_10000.csv  0.658351   0.638206
# 4                        0.1                     0.05  5041.0  5004.0
# 5                        0.1                     0.05  5250.0  4830.0
# 6                        0.1                     0.05  5001.0  5119.0
# 7                        0.1                     0.05  5273.0  4943.0
# 8                        0.1                     0.05  5040.0  5210.0
# 9                        0.1                     0.05  5356.0  4724.0
# 10                       0.1                     0.05  5081.0  5230.0
# 11                       0.1                     0.05  4998.0  5179.0
# 12                       0.1                     0.05  4994.0  5259.0
# 13                       0.1                     0.05  4759.0  5513.0
# 14                       0.1                     0.05  5070.0  5077.0
# 15                       0.1                     0.05  5062.0  5125.0
# 16                       0.1                     0.05  5146.0  5131.0
# 17                       0.1                     0.05  4920.0  5282.0
# 18                       0.1                     0.05  5139.0  5140.0
# 19                       0.1                     0.05  5235.0  5016.0
# 20                       0.1                     0.05  5021.0  5236.0
# 21                       0.1                     0.05  5126.0  5109.0
# 22                       0.1                     0.05  5079.0  5206.0
# 23                       0.1                     0.05  5197.0  5146.0
# 24                       0.1                     0.05  5053.0  5201.0

# %%
res_3.to_csv('KNN_PCA_TrainTestSize.csv')

# %%
#Experimentamos variando el tamaño del train test
#KNN
import sys
from multiprocessing import Pool

def run_grid_in_parallel(grid, n_proc=18):
    """Run a grid on n_proc workers"""
    done, results = 0, []
    
    def call_back(out):
        nonlocal done
        nonlocal results
        results.append(out)
        done += 1
        print('\r', f'Point {done}/{len(grid)} done', end='         ')
        sys.stdout.flush()

    with Pool(n_proc) as pool:
        for point in grid:
            pool.apply_async(run, args=(EXEC_PATH, point, ), callback=call_back)
        pool.close()
        pool.join()
    return pd.DataFrame(results)

file_names = ['../data/train_test_sample_' + str(i) + '.csv' for i in range(1000,25001,1000)]
grid_ranges = {
    'dataset': file_names,
    'output_file': ['../../datos/out.csv'], # Todavia no hace nada
    'mode': [0],
    'k': [15],
    'alpha': [0],
    'threshold_frecuency_low': [0.05],
    'threshold_frecuency_high': [0.1],
}
grid = list(build_grid(grid_ranges))
res_4 = run_grid_in_parallel(grid)
# Out:
#  Point 25/25 done

# %%
res_4
# Out:
#     Accuracy                         Dataset File        F1  Precision  \
# 0   0.631301   ../data/train_test_sample_1000.csv  0.585995   0.521136
# 1   0.643229   ../data/train_test_sample_2000.csv  0.615473   0.569829
# 2   0.638117   ../data/train_test_sample_3000.csv  0.666009   0.723464
# 3   0.669804   ../data/train_test_sample_4000.csv  0.673185   0.677256
# 4   0.659235   ../data/train_test_sample_5000.csv  0.677164   0.712821
# 5   0.666400   ../data/train_test_sample_6000.csv  0.649263   0.624882
# 6   0.660992   ../data/train_test_sample_7000.csv  0.642092   0.608225
# 7   0.669003   ../data/train_test_sample_8000.csv  0.666846   0.664569
# 8   0.665688   ../data/train_test_sample_9000.csv  0.642857   0.600799
# 9   0.661750  ../data/train_test_sample_10000.csv  0.665964   0.682518
# 10  0.671430  ../data/train_test_sample_11000.csv  0.675802   0.680600
# 11  0.676659  ../data/train_test_sample_12000.csv  0.672217   0.660197
# 12  0.668291  ../data/train_test_sample_13000.csv  0.677942   0.703280
# 13  0.670471  ../data/train_test_sample_14000.csv  0.687472   0.721116
# 14  0.679551  ../data/train_test_sample_15000.csv  0.688797   0.708361
# 15  0.678419  ../data/train_test_sample_16000.csv  0.688527   0.711441
# 16  0.677258  ../data/train_test_sample_17000.csv  0.678716   0.683668
# 17  0.678018  ../data/train_test_sample_18000.csv  0.687492   0.708144
# 18  0.674299  ../data/train_test_sample_19000.csv  0.681673   0.704803
# 19  0.674633  ../data/train_test_sample_20000.csv  0.680979   0.703258
# 20  0.677327  ../data/train_test_sample_21000.csv  0.685290   0.696954
# 21  0.674811  ../data/train_test_sample_22000.csv  0.683228   0.703684
# 22  0.679044  ../data/train_test_sample_23000.csv  0.685964   0.702583
# 23  0.683265  ../data/train_test_sample_24000.csv  0.686819   0.700646
# 24  0.678502  ../data/train_test_sample_25000.csv  0.684854   0.694810
sys
from multiprocessing import Pool

def run_grid_in_parallel(grid, n_proc=18):
    """Run a grid on n_proc workers"""
    done, results = 0, []
    
    def call_back(out):
        nonlocal done
        nonlocal results
        results.append(out)
        done += 1
        print('\r', f'Point {done}/{len(grid)} done', end='         ')
        sys.stdout.flush()

    with Pool(n_proc) as pool:
        for point in grid:
            pool.apply_async(run, args=(EXEC_PATH, point, ), callback=call_back)
        pool.close()
        pool.join()
    return pd.DataFrame(results)

file_names = ['../data/train_test_sample_' + str(i) + '.csv' for i in range(1000,25001,2000)]
grid_ranges = {
    'dataset': file_names,
    'output_file': ['../../datos/out.csv'], # Todavia no hace nada
    'mode': [1],
    'k': [1, 2, 3, 5, 7, 9, 10, 15, 20, 50, 100, 250, 500],
    'alpha': [50],
    'threshold_frecuency_low': [0.05],
    'threshold_frecuency_high': [0.1],
}
grid = list(build_grid(grid_ranges))
res_5 = run_grid_in_parallel(grid)
# Out:
#  Point 169/169 done

# %%
res_5
# Out:
#      Accuracy                         Dataset File        F1  Precision  \
# 0    0.574748   ../data/train_test_sample_1000.csv  0.582224   0.591812
# 1    0.641984   ../data/train_test_sample_1000.csv  0.631781   0.613415
# 2    0.594779   ../data/train_test_sample_1000.csv  0.607210   0.625550
# 3    0.672631   ../data/train_test_sample_1000.csv  0.683575   0.706227
# 4    0.677572   ../data/train_test_sample_1000.csv  0.705818   0.772503
# 5    0.616345   ../data/train_test_sample_1000.csv  0.634478   0.665022
# 6    0.636643   ../data/train_test_sample_1000.csv  0.651912   0.679557
# 7    0.632169   ../data/train_test_sample_1000.csv  0.498589   0.365249
# 8    0.628230   ../data/train_test_sample_1000.csv  0.611065   0.583278
# 9    0.570007   ../data/train_test_sample_1000.csv  0.462437   0.369383
# 10   0.659945   ../data/train_test_sample_1000.csv  0.657889   0.653020
# 11   0.608333   ../data/train_test_sample_1000.csv  0.626987   0.657421
# 12   0.622288   ../data/train_test_sample_1000.csv  0.640848   0.673023
# 13   0.588451   ../data/train_test_sample_3000.csv  0.593418   0.602195
# 14   0.613752   ../data/train_test_sample_3000.csv  0.622619   0.638870
# 15   0.636849   ../data/train_test_sample_3000.csv  0.650834   0.678624
# 16   0.580374   ../data/train_test_sample_3000.csv  0.467829   0.369830
# 17   0.627837   ../data/train_test_sample_3000.csv  0.640578   0.664971
# 18   0.679439   ../data/train_test_sample_3000.csv  0.704310   0.765493
# 19   0.689586   ../data/train_test_sample_3000.csv  0.734740   0.862000
# 20   0.676168   ../data/train_test_sample_3000.csv  0.693111   0.733235
# 21   0.657877   ../data/train_test_sample_3000.csv  0.658629   0.661759
# 22   0.648932   ../data/train_test_sample_3000.csv  0.665437   0.700040
# 23   0.691121   ../data/train_test_sample_3000.csv  0.726488   0.822514
# 24   0.642790   ../data/train_test_sample_3000.csv  0.657097   0.686254
# 25   0.639119   ../data/train_test_sample_3000.csv  0.622697   0.597109
# 26   0.645685   ../data/train_test_sample_5000.csv  0.644665   0.641060
# 27   0.630131   ../data/train_test_sample_5000.csv  0.629340   0.626281
# 28   0.585608   ../data/train_test_sample_5000.csv  0.462697   0.355878
# 29   0.654763   ../data/train_test_sample_5000.csv  0.653119   0.648249
# ..        ...                                  ...       ...        ...
# 139  0.703031  ../data/train_test_sample_21000.csv  0.703229   0.698013
# 140  0.709040  ../data/train_test_sample_21000.csv  0.710701   0.709007
# 141  0.712178  ../data/train_test_sample_21000.csv  0.712504   0.707550
# 142  0.713046  ../data/train_test_sample_21000.csv  0.711466   0.701854
# 143  0.623214  ../data/train_test_sample_23000.csv  0.622659   0.623076
# 144  0.608054  ../data/train_test_sample_23000.csv  0.502754   0.397136
# 145  0.650594  ../data/train_test_sample_23000.csv  0.650361   0.651318
# 4                         0.1                     0.05  4355.0  5793.0
# 5                         0.1                     0.05  4244.0  4987.0
# 6                         0.1                     0.05  4439.0  5096.0
# 7                         0.1                     0.05  6729.0  2739.0
# 8                         0.1                     0.05  5035.0  4374.0
# 9                         0.1                     0.05  5767.0  2770.0
# 10                        0.1                     0.05  4987.0  4897.0
# 11                        0.1                     0.05  4181.0  4930.0
# 12                        0.1                     0.05  4273.0  5047.0
# 13                        0.1                     0.05  4316.0  4499.0
# 14                        0.1                     0.05  4421.0  4773.0
# 15                        0.1                     0.05  4470.0  5070.0
# 16                        0.1                     0.05  5931.0  2763.0
# 17                        0.1                     0.05  4437.0  4968.0
# 18                        0.1                     0.05  4459.0  5719.0
# 19                        0.1                     0.05  3890.0  6440.0
# 20                        0.1                     0.05  4651.0  5478.0
# 21                        0.1                     0.05  4911.0  4944.0
# 22                        0.1                     0.05  4491.0  5230.0
# 23                        0.1                     0.05  4208.0  6145.0
# 24                        0.1                     0.05  4502.0  5127.0
# 25                        0.1                     0.05  5113.0  4461.0
# 26                        0.1                     0.05  4858.0  4815.0
# 27                        0.1                     0.05  4736.0  4704.0
# 28                        0.1                     0.05  6100.0  2673.0
# 29                        0.1                     0.05  4940.0  4869.0
# ..                        ...                      ...     ...     ...
# 139                       0.1                     0.05  5260.0  5270.0
# 140                       0.1                     0.05  5267.0  5353.0
# 141                       0.1                     0.05  5325.0  5342.0
# 142                       0.1                     0.05  5381.0  5299.0
# 143                       0.1                     0.05  4677.0  4655.0
# 144                       0.1                     0.05  6138.0  2967.0
# 145                       0.1                     0.05  4876.0  4866.0
# 146                       0.1                     0.05  4930.0  4960.0
# 147                       0.1                     0.05  4985.0  5023.0
# 148                       0.1                     0.05  5535.0  4486.0
# 149                       0.1                     0.05  5002.0  5058.0
# 150                       0.1                     0.05  5079.0  5206.0
# 151                       0.1                     0.05  5390.0  4895.0
# 152                       0.1                     0.05  5361.0  5173.0
# 153                       0.1                     0.05  5359.0  5300.0
# 154                       0.1                     0.05  5415.0  5272.0
# 155                       0.1                     0.05  5478.0  5228.0
# 156                       0.1                     0.05  4649.0  4606.0
# 157                       0.1                     0.05  6067.0  3029.0
# 158                       0.1                     0.05  4868.0  4892.0
# 159                       0.1                     0.05  4919.0  5000.0
# 160                       0.1                     0.05  4985.0  5062.0
# 161                       0.1                     0.05  4965.0  5130.0
# 162                       0.1                     0.05  5498.0  4542.0
# 163                       0.1                     0.05  5385.0  4916.0
# 164                       0.1                     0.05  5053.0  5201.0
# 165                       0.1                     0.05  5328.0  5248.0
# 166                       0.1                     0.05  5305.0  5329.0
# 167                       0.1                     0.05  5339.0  5397.0
# 168                       0.1                     0.05  5362.0  5395.0
#
# [169 rows x 15 columns]

# %%
res_5.to_csv('KNN_PCA_TrainTestSize_and_K.csv')

# %%
#Experimentamos variando el tamaño del train test y k
#KNN

import sys
from multiprocessing import Pool

def run_grid_in_parallel(grid, n_proc=18):
    """Run a grid on n_proc workers"""
    done, results = 0, []
    
    def call_back(out):
        nonlocal done
        nonlocal results
        results.append(out)
        done += 1
        print('\r', f'Point {done}/{len(grid)} done', end='         ')
        sys.stdout.flush()

    with Pool(n_proc) as pool:
        for point in grid:
            pool.apply_async(run, args=(EXEC_PATH, point, ), callback=call_back)
        pool.close()
        pool.join()
    return pd.DataFrame(results)

file_names = ['../data/train_test_sample_' + str(i) + '.csv' for i in range(1000,25001,2000)]
grid_ranges = {
    'dataset': file_names,
    'output_file': ['../../datos/out.csv'], # Todavia no hace nada
    'mode': [0],
    'k': [1, 2, 3, 5, 7, 9, 10, 15, 20, 50, 100, 250, 500],
    'alpha': [0],
    'threshold_frecuency_low': [0.05],
    'threshold_frecuency_high': [0.1],
}
grid = list(build_grid(grid_ranges))
res_6 = run_grid_in_parallel(grid)
# Out:
#  Point 169/169 done

# %%
res_6
# Out:
#      Accuracy                         Dataset File        F1  Precision  \
# 0    0.565400   ../data/train_test_sample_1000.csv  0.429885   0.327244
# 1    0.657475   ../data/train_test_sample_1000.csv  0.673123   0.704361
# 2    0.619617   ../data/train_test_sample_1000.csv  0.592577   0.552474
# 3    0.608533   ../data/train_test_sample_1000.csv  0.591058   0.565009
# 4    0.591841   ../data/train_test_sample_1000.csv  0.581788   0.567009
# 5    0.620151   ../data/train_test_sample_1000.csv  0.521973   0.414189
# 6    0.631301   ../data/train_test_sample_1000.csv  0.585995   0.521136
# 7    0.611671   ../data/train_test_sample_1000.csv  0.523201   0.425523
# 8    0.630834   ../data/train_test_sample_1000.csv  0.539978   0.432724
# 9    0.669760   ../data/train_test_sample_1000.csv  0.619011   0.535805
# 10   0.568538   ../data/train_test_sample_1000.csv  0.568164   0.566876
# 11   0.644588   ../data/train_test_sample_1000.csv  0.718732   0.906921
# 12   0.626494   ../data/train_test_sample_1000.csv  0.595458   0.549007
# 13   0.615087   ../data/train_test_sample_3000.csv  0.637905   0.679829
# 14   0.618425   ../data/train_test_sample_3000.csv  0.642795   0.688395
# 15   0.576769   ../data/train_test_sample_3000.csv  0.594940   0.623210
# 16   0.579640   ../data/train_test_sample_3000.csv  0.484486   0.396065
# 17   0.597597   ../data/train_test_sample_3000.csv  0.618384   0.653728
# 18   0.706676   ../data/train_test_sample_3000.csv  0.703108   0.696426
# 19   0.664820   ../data/train_test_sample_3000.csv  0.676211   0.701780
# 20   0.688518   ../data/train_test_sample_3000.csv  0.729256   0.841119
# 21   0.629506   ../data/train_test_sample_3000.csv  0.618452   0.602061
# 22   0.673765   ../data/train_test_sample_3000.csv  0.676465   0.683844
# 23   0.650000   ../data/train_test_sample_3000.csv  0.655677   0.668184
# 24   0.627704   ../data/train_test_sample_3000.csv  0.652545   0.700977
# 25   0.638117   ../data/train_test_sample_3000.csv  0.666009   0.723464
# 26   0.587477   ../data/train_test_sample_5000.csv  0.491023   0.396885
# 27   0.625526   ../data/train_test_sample_5000.csv  0.644442   0.676874
# 28   0.586810   ../data/train_test_sample_5000.csv  0.599974   0.618027
# 29   0.632735   ../data/train_test_sample_5000.csv  0.652256   0.686992
# ..        ...                                  ...       ...        ...
# 139  0.704433  ../data/train_test_sample_21000.csv  0.699722   0.683179
# 140  0.712245  ../data/train_test_sample_21000.csv  0.703943   0.678675
# 141  0.709441  ../data/train_test_sample_21000.csv  0.687715   0.634702
# 142  0.706703  ../data/train_test_sample_21000.csv  0.670467   0.591921
# 143  0.608254  ../data/train_test_sample_23000.csv  0.608359   0.609825
# 144  0.598838  ../data/train_test_sample_23000.csv  0.492180   0.389640
# 145  0.631428  ../data/train_test_sample_23000.csv  0.633849   0.639406
# 146  0.644183  ../data/train_test_sample_23000.csv  0.649012   0.659349
# 147  0.655202  ../data/train_test_sample_23000.csv  0.660664   0.672735
# 148  0.660211  ../data/train_test_sample_23000.csv  0.665966   0.678892
# 149  0.664685  ../data/train_test_sample_23000.csv  0.642862   0.604872
# 150  0.679044  ../data/train_test_sample_23000.csv  0.685964   0.702583
# 151  0.683251  ../data/train_test_sample_23000.csv  0.674356   0.657342
# 152  0.702418  ../data/train_test_sample_23000.csv  0.698878   0.692143
# 153  0.717644  ../data/train_test_sample_23000.csv  0.701244   0.664168
# 154  0.712301  ../data/train_test_sample_23000.csv  0.706219   0.693080
# 155  0.711300  ../data/train_test_sample_23000.csv  0.679849   0.614376
# 156  0.609624  ../data/train_test_sample_25000.csv  0.609468   0.605868
# 157  0.596409  ../data/train_test_sample_25000.csv  0.490436   0.386300
# 158  0.632851  ../data/train_test_sample_25000.csv  0.635478   0.636533
# 159  0.646132  ../data/train_test_sample_25000.csv  0.650771   0.655781
# 160  0.659481  ../data/train_test_sample_25000.csv  0.664077   0.669454
# 161  0.666555  ../data/train_test_sample_25000.csv  0.671661   0.678349
# 162  0.663952  ../data/train_test_sample_25000.csv  0.640639   0.595779
# 163  0.678502  ../data/train_test_sample_25000.csv  0.684854   0.694810
# 164  0.685510  ../data/train_test_sample_25000.csv  0.676596   0.654321
# 165  0.700994  ../data/train_test_sample_25000.csv  0.698316   0.688305
# 166  0.715745  ../data/train_test_sample_25000.csv  0.702355   0.667065
# 167  0.712007  ../data/train_test_sample_25000.csv  0.707279   0.692022
# 168  0.715144  ../data/train_test_sample_25000.csv  0.690141   0.630957
#
#        Recall       Time  alpha      fn      fp      k  mode  \
# 0    0.626340    5.23086    0.0  5045.0  1464.0    2.0   0.0
# 1    0.644539    5.22908    0.0  2217.0  2913.0  100.0   0.0
# 2    0.638957    5.33733    0.0  3356.0  2341.0    7.0   0.0
# 3    0.619626    5.38600    0.0  3262.0  2601.0    5.0   0.0
# 4    0.597359    5.38469    0.0  3247.0  2866.0    3.0   0.0
# 5    0.705588    5.39023    0.0  4393.0  1296.0   20.0   0.0
# 6    0.669293    5.38581    0.0  3591.0  1931.0   15.0   0.0
# 7    0.679081    5.41744    0.0  4308.0  1508.0   10.0   0.0
# 8    0.717920    5.37294    0.0  4254.0  1275.0   50.0   0.0
# 9    0.732811    5.44633    0.0  3481.0  1465.0  500.0   0.0
# 10   0.569457    5.45188    0.0  3248.0  3214.0    1.0   0.0
# 11   0.595221    5.56431    0.0   698.0  4625.0  250.0   0.0
# 12   0.650498    5.60026    0.0  3382.0  2212.0    9.0   0.0
# 13   0.600852   22.37700    0.0  2392.0  3374.0    5.0   0.0
# 14   0.602860   22.71080    0.0  2328.0  3388.0    7.0   0.0
# 15   0.569124   22.73440    0.0  2815.0  3525.0    1.0   0.0
