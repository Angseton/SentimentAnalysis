# %%
import pandas as pd
import numpy as np
import subprocess
from itertools import chain, product

# %%
PARAMS_TO_FLAGS = {
    'dataset': '-i',
    'output_file': '-o',
    'mode': '-m',
    'k': '-k',
    'alpha': '-a',
    'threshold_frecuency_low': '-f_low',
    'threshold_frecuency_high': '-f_high',
}

def build_grid(ranges):
    """Build grid based on ranges."""
    def as_list(elmt):
        """Convert elmt to list if elmt is not list."""
        if isinstance(elmt, list):
            return elmt
        else:
            return [elmt]

    grid = product(*(as_list(i) for i in ranges.values()))
    for p in grid:
        yield (dict(zip(ranges.keys(), p)))

# %%
grid_ranges = {
    'dataset': ['../data/train_test_sample_1000.csv'],
    'output_file': ['../../datos/out.csv'], # Todavia no hace nada
    'mode': [0, 1],
    'k': [1, 2, 3, 4, 5, 10, 20, 30, 50],
    'alpha': [0, 1, 5, 10, 15, 20, 25, 30, 50],
    'threshold_frecuency_low': [0.01],
    'threshold_frecuency_high': [0.99],
}

# Un generator(iterador) de los puntos de la grilla
grid = list(build_grid(ranges=grid_ranges))
print(grid[0])
print(grid[1])
print(grid[2])
# Out:
# {'dataset': '../data/train_test_sample_1000.csv', 'output_file': '../../datos/out.csv', 'mode': 0, 'k': 1, 'alpha': 0, 'threshold_frecuency_low': 0.01, 'threshold_frecuency_high': 0.99}
# {'dataset': '../data/train_test_sample_1000.csv', 'output_file': '../../datos/out.csv', 'mode': 0, 'k': 1, 'alpha': 1, 'threshold_frecuency_low': 0.01, 'threshold_frecuency_high': 0.99}
# {'dataset': '../data/train_test_sample_1000.csv', 'output_file': '../../datos/out.csv', 'mode': 0, 'k': 1, 'alpha': 5, 'threshold_frecuency_low': 0.01, 'threshold_frecuency_high': 0.99}

# %%
def parse_results(output, niters):
    N, time, eigen_val, *eigen_vec = list(map(float, output.decode().split('\n')[:-1]))
    return {
        'N': N,
        'time': time,
        'niters': niters,
        'eigen_val': eigen_val,
        'eigen_vec': np.array(eigen_vec),
    }


def output_to_dict(output):
    # Parsear la salida a un diccionario
    lines = output.decode().split('\n')
    d = dict(tuple(l.split(': ')) for l in lines if ': ' in l)
    for k, v in d.items():
        if k != 'Dataset File':
            d[k] = float(v)
    return d

def run(exc_path, params):
    args = tuple(chain(*((PARAMS_TO_FLAGS[p], str(v)) for p, v in params.items())))
    args = [exc_path, *args]
    output = subprocess.check_output(args)
    return output_to_dict(output)

# %%
EXEC_PATH = '../executables/tp2'
param_set = {
    'dataset': '../data/train_test_sample_1000.csv', 
    'output_file': '../../datos/out.csv', 
    'mode': 0, 
    'k': 1, 
    'alpha': 0, 
    'threshold_frecuency_low': 0.01, 
    'threshold_frecuency_high': 0.99
}
out = run(EXEC_PATH, param_set)
out
# Out:
# {'Dataset File': '../data/train_test_sample_1000.csv',
#  'mode': 0.0,
#  'k': 1.0,
#  'alpha': 0.0,
#  'threshold_frecuency_low': 0.01,
#  'threshold_frecuency_high': 0.99,
#  'tp': 713.0,
#  'fp': 437.0,
#  'tn': 788.0,
#  'fn': 562.0,
#  'Accuracy': 0.6004,
#  'Precision': 0.559216,
#  'Recall': 0.62,
#  'F1': 0.588041,
#  'Time': 11.528}

# %%
# Correrlo para una grilla chica para ver que pasa con los thresholds
grid_ranges = {
    'dataset': ['../data/train_test_sample_1000.csv'],
    'output_file': ['../../datos/out.csv'], # Todavia no hace nada
    'mode': [0],
    'k': [5],
    'alpha': [0],
    'threshold_frecuency_low': [0.01, 0.05, 0.1, 0.15, 0.2, 0.25],
    'threshold_frecuency_high': [0.8, 0.85, 0.9, 0.95, 0.99],
}
results = []
grid = list(build_grid(grid_ranges))
for i, point in enumerate(grid):
    print('\r', f'Running for point {i+1}/{len(grid)}', end='         ')
    out = run(EXEC_PATH, point)
    results.append(out)
results_df = pd.DataFrame(results)
# Out:
#  Running for point 30/30

# %%
results_df.head()
# Out:
#    Accuracy                        Dataset File        F1  Precision  \
# 0    0.5792  ../data/train_test_sample_1000.csv  0.574089   0.556078
# 1    0.5884  ../data/train_test_sample_1000.csv  0.583232   0.564706
# 2    0.5932  ../data/train_test_sample_1000.csv  0.588759   0.570980
# 3    0.5896  ../data/train_test_sample_1000.csv  0.580196   0.556078
# 4    0.6004  ../data/train_test_sample_1000.csv  0.588041   0.559216
#
#      Recall     Time  alpha     fn     fp    k  mode  \
# 0  0.593305  4.93782    0.0  566.0  486.0  5.0   0.0
# 1  0.603015  4.97401    0.0  555.0  474.0  5.0   0.0
# 2  0.607679  4.92615    0.0  547.0  470.0  5.0   0.0
# 3  0.606501  4.96373    0.0  566.0  460.0  5.0   0.0
# 4  0.620000  4.98864    0.0  562.0  437.0  5.0   0.0
#
#    threshold_frecuency_high  threshold_frecuency_low     tn     tp
# 0                      0.80                     0.01  739.0  709.0
# 1                      0.85                     0.01  751.0  720.0
# 2                      0.90                     0.01  755.0  728.0
# 3                      0.95                     0.01  765.0  709.0
# 4                      0.99                     0.01  788.0  713.0

# %%
# results_df.sort_values('Accuracy')

# %%
# pareceria ser que los valores de los thresholds en 0.2 y 0.95 son los mejores.
# Igual es un conjunto de datos bastante chico habria que probar con mas datos

# %%
import sys
from multiprocessing import Pool

def run_grid_in_parallel(grid, n_proc=18):
    """Run a grid on n_proc workers"""
    done, results = 0, []
    
    def call_back(out):
        nonlocal done
        nonlocal results
        results.append(out)
        done += 1
        print('\r', f'Point {done}/{len(grid)} done', end='         ')
        sys.stdout.flush()

    with Pool(n_proc) as pool:
        for point in grid:
            pool.apply_async(run, args=(EXEC_PATH, point, ), callback=call_back)
        pool.close()
        pool.join()
    return pd.DataFrame(results)

grid_ranges = {
    'dataset': ['../data/train_test_sample_1000.csv'],
    'output_file': ['../../datos/out.csv'], # Todavia no hace nada
    'mode': [0],
    'k': [5],
    'alpha': [0],
    'threshold_frecuency_low': [0.01, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.4, 0.5],
    'threshold_frecuency_high': [0.7, 0.75, 0.8, 0.85, 0.9, 0.95, 0.99],
}
grid = list(build_grid(grid_ranges))
res = run_grid_in_parallel(grid)
# Out:
#  Point 63/63 done

# %%
res.sort_values('Accuracy', ascending=False).head()
# Out:
#     Accuracy                        Dataset File        F1  Precision  \
# 8     0.6104  ../data/train_test_sample_1000.csv  0.592469   0.555294
# 4     0.6056  ../data/train_test_sample_1000.csv  0.590191   0.556863
# 5     0.6040  ../data/train_test_sample_1000.csv  0.594262   0.568627
# 14    0.6040  ../data/train_test_sample_1000.csv  0.594262   0.568627
# 1     0.6020  ../data/train_test_sample_1000.csv  0.587308   0.555294
#
#       Recall     Time  alpha     fn     fp    k  mode  \
# 8   0.634978  2.26049    0.0  567.0  407.0  5.0   0.0
# 4   0.627763  2.20125    0.0  565.0  421.0  5.0   0.0
# 5   0.622318  2.21171    0.0  550.0  440.0  5.0   0.0
# 14  0.622318  1.06052    0.0  550.0  440.0  5.0   0.0
# 1   0.623239  1.04956    0.0  567.0  428.0  5.0   0.0
#
#     threshold_frecuency_high  threshold_frecuency_low     tn     tp
# 8                       0.70                     0.05  818.0  708.0
# 4                       0.75                     0.05  804.0  710.0
# 5                       0.99                     0.05  785.0  725.0
# 14                      0.99                     0.10  785.0  725.0
# 1                       0.70                     0.10  797.0  708.0

# %%
def score_metrics(scores, metrics=['Accuracy', 'F1','Precision', 'Recall'], top=5):
    for metric in metrics:
        for t in range(top):
            scores.sort_values(metric, ascending=False).iloc[t]

# %%
import sys
from multiprocessing import Pool

def run_grid_in_parallel(grid, n_proc=18):
    """Run a grid on n_proc workers"""
    done, results = 0, []
    
    def call_back(out):
        nonlocal done
        nonlocal results
        results.append(out)
        done += 1
        print('\r', f'Point {done}/{len(grid)} done', end='         ')
        sys.stdout.flush()

    with Pool(n_proc) as pool:
        for point in grid:
            pool.apply_async(run, args=(EXEC_PATH, point, ), callback=call_back)
        pool.close()
        pool.join()
    return pd.DataFrame(results)

grid_ranges = {
    'dataset': ['../data/train_test_sample_1000.csv'],
    'output_file': ['../../datos/out.csv'], # Todavia no hace nada
    'mode': [1],
    'k': [1, 2, 3, 5, 7, 9, 10, 15, 20],
    'alpha': [25, 50, 75, 100, 150],
    'threshold_frecuency_low': [0.05],
    'threshold_frecuency_high': [0.99],
}
grid = list(build_grid(grid_ranges))
res_2 = run_grid_in_parallel(grid)
# Out:
#  Point 45/45 done

# %%
res_2.sort_values('Precision', ascending=False)
# Out:
#     Accuracy                        Dataset File        F1  Precision  \
# 22    0.6004  ../data/train_test_sample_1000.csv  0.593737   0.572549
# 38    0.6004  ../data/train_test_sample_1000.csv  0.593737   0.572549
# 26    0.6004  ../data/train_test_sample_1000.csv  0.593737   0.572549
# 30    0.6004  ../data/train_test_sample_1000.csv  0.593737   0.572549
# 12    0.6004  ../data/train_test_sample_1000.csv  0.593737   0.572549
# 37    0.6004  ../data/train_test_sample_1000.csv  0.593737   0.572549
# 11    0.6004  ../data/train_test_sample_1000.csv  0.593737   0.572549
# 5     0.6004  ../data/train_test_sample_1000.csv  0.593737   0.572549
# 3     0.6004  ../data/train_test_sample_1000.csv  0.593737   0.572549
# 41    0.5940  ../data/train_test_sample_1000.csv  0.588569   0.569412
# 6     0.5940  ../data/train_test_sample_1000.csv  0.588569   0.569412
# 23    0.5940  ../data/train_test_sample_1000.csv  0.588569   0.569412
# 4     0.5940  ../data/train_test_sample_1000.csv  0.588569   0.569412
# 36    0.5940  ../data/train_test_sample_1000.csv  0.588569   0.569412
# 14    0.5940  ../data/train_test_sample_1000.csv  0.588569   0.569412
# 19    0.5940  ../data/train_test_sample_1000.csv  0.588569   0.569412
# 2     0.5940  ../data/train_test_sample_1000.csv  0.588569   0.569412
# 24    0.5940  ../data/train_test_sample_1000.csv  0.588569   0.569412
# 43    0.6052  ../data/train_test_sample_1000.csv  0.591643   0.560784
# 35    0.6052  ../data/train_test_sample_1000.csv  0.591643   0.560784
# 34    0.6052  ../data/train_test_sample_1000.csv  0.591643   0.560784
# 32    0.6052  ../data/train_test_sample_1000.csv  0.591643   0.560784
# 25    0.6052  ../data/train_test_sample_1000.csv  0.591643   0.560784
# 44    0.6052  ../data/train_test_sample_1000.csv  0.591643   0.560784
# 16    0.6052  ../data/train_test_sample_1000.csv  0.591643   0.560784
# 15    0.6052  ../data/train_test_sample_1000.csv  0.591643   0.560784
# 13    0.6052  ../data/train_test_sample_1000.csv  0.591643   0.560784
# 20    0.5984  ../data/train_test_sample_1000.csv  0.586831   0.559216
# 42    0.5984  ../data/train_test_sample_1000.csv  0.586831   0.559216
# 29    0.5984  ../data/train_test_sample_1000.csv  0.586831   0.559216
# 31    0.5984  ../data/train_test_sample_1000.csv  0.586831   0.559216
# 17    0.5984  ../data/train_test_sample_1000.csv  0.586831   0.559216
# 33    0.5984  ../data/train_test_sample_1000.csv  0.586831   0.559216
# 40    0.5984  ../data/train_test_sample_1000.csv  0.586831   0.559216
# 10    0.5984  ../data/train_test_sample_1000.csv  0.586831   0.559216
# 9     0.5984  ../data/train_test_sample_1000.csv  0.586831   0.559216
# 39    0.5852  ../data/train_test_sample_1000.csv  0.562632   0.523137
# 7     0.5852  ../data/train_test_sample_1000.csv  0.562632   0.523137
# 8     0.5852  ../data/train_test_sample_1000.csv  0.562632   0.523137
# 1     0.5852  ../data/train_test_sample_1000.csv  0.562632   0.523137
# 21    0.5852  ../data/train_test_sample_1000.csv  0.562632   0.523137
# 18    0.5852  ../data/train_test_sample_1000.csv  0.562632   0.523137
# 28    0.5852  ../data/train_test_sample_1000.csv  0.562632   0.523137
# 27    0.5852  ../data/train_test_sample_1000.csv  0.562632   0.523137
# 0     0.5852  ../data/train_test_sample_1000.csv  0.562632   0.523137
#
#       Recall     Time  alpha     fn     fp     k  mode  \
# 22  0.616554  23.3296   75.0  545.0  454.0   7.0   1.0
# 38  0.616554  14.6964   75.0  545.0  454.0  20.0   1.0
# 26  0.616554  23.0277   75.0  545.0  454.0  10.0   1.0
shold_frecuency_high  threshold_frecuency_low     tn     tp
# 22                      0.99                     0.05  771.0  730.0
# 38                      0.99                     0.05  771.0  730.0
# 26                      0.99                     0.05  771.0  730.0
# 30                      0.99                     0.05  771.0  730.0
# 12                      0.99                     0.05  771.0  730.0
# 37                      0.99                     0.05  771.0  730.0
# 11                      0.99                     0.05  771.0  730.0
# 5                       0.99                     0.05  771.0  730.0
# 3                       0.99                     0.05  771.0  730.0
# 41                      0.99                     0.05  759.0  726.0
# 6                       0.99                     0.05  759.0  726.0
# 23                      0.99                     0.05  759.0  726.0
# 4                       0.99                     0.05  759.0  726.0
# 36                      0.99                     0.05  759.0  726.0
# 14                      0.99                     0.05  759.0  726.0
# 19                      0.99                     0.05  759.0  726.0
# 2                       0.99                     0.05  759.0  726.0
# 24                      0.99                     0.05  759.0  726.0
# 43                      0.99                     0.05  798.0  715.0
# 35                      0.99                     0.05  798.0  715.0
# 34                      0.99                     0.05  798.0  715.0
# 32                      0.99                     0.05  798.0  715.0
# 25                      0.99                     0.05  798.0  715.0
# 44                      0.99                     0.05  798.0  715.0
# 16                      0.99                     0.05  798.0  715.0
# 15                      0.99                     0.05  798.0  715.0
# 13                      0.99                     0.05  798.0  715.0
# 20                      0.99                     0.05  783.0  713.0
# 42                      0.99                     0.05  783.0  713.0
# 29                      0.99                     0.05  783.0  713.0
# 31                      0.99                     0.05  783.0  713.0
# 17                      0.99                     0.05  783.0  713.0
# 33                      0.99                     0.05  783.0  713.0
# 40                      0.99                     0.05  783.0  713.0
# 10                      0.99                     0.05  783.0  713.0
# 9                       0.99                     0.05  783.0  713.0
# 39                      0.99                     0.05  796.0  667.0
# 7                       0.99                     0.05  796.0  667.0
# 8                       0.99                     0.05  796.0  667.0
# 1                       0.99                     0.05  796.0  667.0
# 21                      0.99                     0.05  796.0  667.0
# 18                      0.99                     0.05  796.0  667.0
# 28                      0.99                     0.05  796.0  667.0
# 27                      0.99                     0.05  796.0  667.0
# 0                       0.99                     0.05  796.0  667.0

# %%
#Experimentamos variando el tamaño del train test
#KNN + PCA
import sys
from multiprocessing import Pool

def run_grid_in_parallel(grid, n_proc=18):
    """Run a grid on n_proc workers"""
    done, results = 0, []
    
    def call_back(out):
        nonlocal done
        nonlocal results
        results.append(out)
        done += 1
        print('\r', f'Point {done}/{len(grid)} done', end='         ')
        sys.stdout.flush()

    with Pool(n_proc) as pool:
        for point in grid:
            pool.apply_async(run, args=(EXEC_PATH, point, ), callback=call_back)
        pool.close()
        pool.join()
    return pd.DataFrame(results)

file_names = ['../data/train_test_sample_' + str(i) + '.csv' for i in range(1000,25001,1000)]
grid_ranges = {
    'dataset': file_names,
    'output_file': ['../../datos/out.csv'], # Todavia no hace nada
    'mode': [1],
    'k': [15],
    'alpha': [50],
    'threshold_frecuency_low': [0.05],
    'threshold_frecuency_high': [0.99],
}
grid = list(build_grid(grid_ranges))
res_3 = run_grid_in_parallel(grid)
# Out:
#  Point 25/25 done

# %%
res_3
# Out:
#     Accuracy                         Dataset File        F1  Precision  \
# 0     0.5940   ../data/train_test_sample_1000.csv  0.588569   0.569412
# 1     0.5976   ../data/train_test_sample_2000.csv  0.599522   0.590588
# 2     0.6204   ../data/train_test_sample_3000.csv  0.594964   0.546667
# 3     0.6040   ../data/train_test_sample_4000.csv  0.592593   0.564706
# 4     0.6136   ../data/train_test_sample_5000.csv  0.616362   0.608627
# 5     0.6056   ../data/train_test_sample_6000.csv  0.596893   0.572549
# 6     0.6152   ../data/train_test_sample_7000.csv  0.607667   0.584314
# 7     0.6256   ../data/train_test_sample_8000.csv  0.608368   0.570196
# 8     0.6208   ../data/train_test_sample_9000.csv  0.619888   0.606275
# 9     0.6204  ../data/train_test_sample_10000.csv  0.613442   0.590588
# 10    0.6368  ../data/train_test_sample_11000.csv  0.621667   0.585098
# 11    0.6292  ../data/train_test_sample_12000.csv  0.620549   0.594510
# 12    0.6316  ../data/train_test_sample_13000.csv  0.630269   0.615686
# 13    0.6516  ../data/train_test_sample_14000.csv  0.648649   0.630588
# 14    0.6348  ../data/train_test_sample_15000.csv  0.637842   0.630588
# 15    0.6508  ../data/train_test_sample_16000.csv  0.654531   0.648627
# 16    0.6308  ../data/train_test_sample_17000.csv  0.625254   0.603922
# 17    0.6352  ../data/train_test_sample_18000.csv  0.633146   0.617255
# 18    0.6432  ../data/train_test_sample_19000.csv  0.640323   0.622745
# 19    0.6272  ../data/train_test_sample_20000.csv  0.623890   0.606275
# 20    0.6456  ../data/train_test_sample_21000.csv  0.641296   0.621176
# 21    0.6392  ../data/train_test_sample_22000.csv  0.636583   0.619608
# 22    0.6472  ../data/train_test_sample_23000.csv  0.645498   0.629804
# 23    0.6456  ../data/train_test_sample_24000.csv  0.643317   0.626667
# 24    0.6432  ../data/train_test_sample_25000.csv  0.643485   0.631373
#
#       Recall     Time  alpha     fn     fp     k  mode  \
# 0   0.609060  23.8505   50.0  549.0  466.0  15.0   1.0
# 1   0.608731  29.2015   50.0  522.0  484.0  15.0   1.0
# 2   0.652622  32.2075   50.0  578.0  371.0  15.0   1.0
# 3   0.623377  36.2984   50.0  555.0  435.0  15.0   1.0
# 4   0.624296  39.5772   50.0  499.0  467.0  15.0   1.0
# 5   0.623399  42.5151   50.0  545.0  441.0  15.0   1.0
# 6   0.632965  45.5954   50.0  530.0  432.0  15.0   1.0
# 7   0.652018  48.7446   50.0  548.0  388.0  15.0   1.0
# 8   0.634126  51.7279   50.0  502.0  446.0  15.0   1.0
# 9   0.638136  54.5909   50.0  522.0  427.0  15.0   1.0
# 10  0.663111  57.3072   50.0  529.0  379.0  15.0   1.0
# 11  0.648973  59.2768   50.0  517.0  410.0  15.0   1.0
# 12  0.645559  62.5439   50.0  490.0  431.0  15.0   1.0
# 13  0.667774  63.3886   50.0  471.0  400.0  15.0   1.0
# 14  0.645265  65.4528   50.0  471.0  442.0  15.0   1.0
# 15  0.660543  67.4984   50.0  448.0  425.0  15.0   1.0
# 16  0.648148  70.5147   50.0  505.0  418.0  15.0   1.0
# 17  0.649876  71.4293   50.0  488.0  424.0  15.0   1.0
# 18  0.658921  65.4204   50.0  481.0  411.0  15.0   1.0
# 19  0.642560  65.5457   50.0  502.0  430.0  15.0   1.0
# 20  0.662762  67.5570   50.0  483.0  403.0  15.0   1.0
# 21  0.654515  67.8495   50.0  485.0  417.0  15.0   1.0
# 22  0.661995  69.1309   50.0  472.0  410.0  15.0   1.0
# 23  0.660877  69.2847   50.0  476.0  410.0  15.0   1.0
# 24  0.656072  70.2461   50.0  470.0  422.0  15.0   1.0
#
#     threshold_frecuency_high  threshold_frecuency_low     tn     tp
# 0                       0.99                     0.05  759.0  726.0
# 1                       0.99                     0.05  741.0  753.0
# 2                       0.99                     0.05  854.0  697.0
# 3                       0.99                     0.05  790.0  720.0
# 4                       0.99                     0.05  758.0  776.0
# 5                       0.99                     0.05  784.0  730.0
# 6                       0.99                     0.05  793.0  745.0
# 7                       0.99                     0.05  837.0  727.0
# 8                       0.99                     0.05  779.0  773.0
# 9                       0.99                     0.05  798.0  753.0
# 10                      0.99                     0.05  846.0  746.0
# 11                      0.99                     0.05  815.0  758.0
# 12                      0.99                     0.05  794.0  785.0
# 13                      0.99                     0.05  825.0  804.0
# 14                      0.99                     0.05  783.0  804.0
# 15                      0.99                     0.05  800.0  827.0
# 16                      0.99                     0.05  807.0  770.0
# 17                      0.99                     0.05  801.0  787.0
# 18                      0.99                     0.05  814.0  794.0
# 19                      0.99                     0.05  795.0  773.0
# 20                      0.99                     0.05  822.0  792.0
# 21                      0.99                     0.05  808.0  790.0
# 22                      0.99                     0.05  815.0  803.0
# 23                      0.99                     0.05  815.0  799.0
# 24                      0.99                     0.05  803.0  805.0

# %%
res_3.to_csv('KNN_PCA_TrainTestSize.csv')

# %%
#Experimentamos variando el tamaño del train test
#KNN
import sys
from multiprocessing import Pool

def run_grid_in_parallel(grid, n_proc=18):
    """Run a grid on n_proc workers"""
    done, results = 0, []
    
    def call_back(out):
        nonlocal done
        nonlocal results
        results.append(out)
        done += 1
        print('\r', f'Point {done}/{len(grid)} done', end='         ')
        sys.stdout.flush()

    with Pool(n_proc) as pool:
        for point in grid:
            pool.apply_async(run, args=(EXEC_PATH, point, ), callback=call_back)
        pool.close()
        pool.join()
    return pd.DataFrame(results)

file_names = ['../data/train_test_sample_' + str(i) + '.csv' for i in range(1000,25001,1000)]
grid_ranges = {
    'dataset': file_names,
    'output_file': ['../../datos/out.csv'], # Todavia no hace nada
    'mode': [0],
    'k': [15],
    'alpha': [0],
    'threshold_frecuency_low': [0.05],
    'threshold_frecuency_high': [0.99],
}
grid = list(build_grid(grid_ranges))
res_4 = run_grid_in_parallel(grid)
# Out:
#  Point 25/25 done

# %%
res_4
# Out:
#     Accuracy                         Dataset File        F1  Precision  \
# 0     0.6040   ../data/train_test_sample_1000.csv  0.594262   0.568627
# 1     0.6052   ../data/train_test_sample_2000.csv  0.605042   0.592941
# 2     0.6252   ../data/train_test_sample_3000.csv  0.552745   0.454118
# 3     0.6048   ../data/train_test_sample_4000.csv  0.591060   0.560000
# 4     0.6116   ../data/train_test_sample_5000.csv  0.620851   0.623529
# 5     0.6052   ../data/train_test_sample_6000.csv  0.584071   0.543529
# 6     0.6196   ../data/train_test_sample_7000.csv  0.596863   0.552157
# 7     0.6256   ../data/train_test_sample_8000.csv  0.604730   0.561569
# 8     0.6156   ../data/train_test_sample_9000.csv  0.600083   0.565490
# 9     0.6328  ../data/train_test_sample_10000.csv  0.627435   0.606275
# 10    0.6284  ../data/train_test_sample_11000.csv  0.607188   0.563137
# 11    0.6212  ../data/train_test_sample_12000.csv  0.610769   0.582745
# 12    0.6340  ../data/train_test_sample_13000.csv  0.624846   0.597647
# 13    0.6308  ../data/train_test_sample_14000.csv  0.617171   0.583529
# 14    0.6340  ../data/train_test_sample_15000.csv  0.626987   0.603137
# 15    0.6268  ../data/train_test_sample_16000.csv  0.624547   0.608627
# 16    0.6208  ../data/train_test_sample_17000.csv  0.615260   0.594510
# 17    0.6260  ../data/train_test_sample_18000.csv  0.616960   0.590588
# 18    0.6412  ../data/train_test_sample_19000.csv  0.636695   0.616471
# 19    0.6340  ../data/train_test_sample_20000.csv  0.616030   0.575686
# 20    0.6296  ../data/train_test_sample_21000.csv  0.613200   0.575686
# 21    0.6392  ../data/train_test_sample_22000.csv  0.631536   0.606275
# 22    0.6324  ../data/train_test_sample_23000.csv  0.621031   0.590588
# 23    0.6244  ../data/train_test_sample_24000.csv  0.607933   0.570980
# 24    0.6288  ../data/train_test_sample_25000.csv  0.616846   0.585882
#
#       Recall       Time  alpha     fn     fp     k  mode  \
# 0   0.622318    5.01979    0.0  550.0  440.0  15.0   0.0
# 1   0.617647   10.54590    0.0  519.0  468.0  15.0   0.0
# 2   0.706098   15.92540    0.0  696.0  241.0  15.0   0.0
# 3   0.625767   21.34900    0.0  561.0  427.0  15.0   0.0
# 4   0.618196   26.97020    0.0  480.0  491.0  15.0   0.0
# 5   0.631148   32.25390    0.0  582.0  405.0  15.0   0.0
# 6   0.649446   37.60130    0.0  571.0  380.0  15.0   0.0
# 7   0.655078   43.10020    0.0  559.0  377.0  15.0   0.0
# 8   0.639184   48.42340    0.0  554.0  407.0  15.0   0.0
# 9   0.650126   53.93360    0.0  502.0  416.0  15.0   0.0
# 10  0.658716   58.74930    0.0  557.0  372.0  15.0   0.0
# 11  0.641623   63.77610    0.0  532.0  415.0  15.0   0.0
# 12  0.654639   68.50180    0.0  513.0  402.0  15.0   0.0
# 13  0.654930   73.05950    0.0  531.0  392.0  15.0   0.0
# 14  0.652801   77.34380    0.0  506.0  409.0  15.0   0.0
# 15  0.641322   81.77230    0.0  499.0  434.0  15.0   0.0
# 16  0.637511   86.50830    0.0  517.0  431.0  15.0   0.0
# 17  0.645798   90.48240    0.0  522.0  413.0  15.0   0.0
# 18  0.658291   92.90580    0.0  489.0  408.0  15.0   0.0
# 19  0.662455   94.72230    0.0  541.0  374.0  15.0   0.0
# 20  0.655943   96.69550    0.0  541.0  385.0  15.0   0.0
# 21  0.658994   98.09300    0.0  502.0  400.0  15.0   0.0
# 22  0.654783   99.38550    0.0  522.0  397.0  15.0   0.0
# 23  0.650000  100.94800    0.0  547.0  392.0  15.0   0.0
# 24  0.651264  100.85000    0.0  528.0  400.0  15.0   0.0
#
#     threshold_frecuency_high  threshold_frecuency_low     tn     tp
# 0                       0.99                     0.05  785.0  725.0
# 1                       0.99                     0.05  757.0  756.0
# 2                       0.99                     0.05  984.0  579.0
# 3                       0.99                     0.05  798.0  714.0
# 4                       0.99                     0.05  734.0  795.0
# 5                       0.99                     0.05  820.0  693.0
# 6                       0.99                     0.05  845.0  704.0
# 7                       0.99                     0.05  848.0  716.0
# 8                       0.99                     0.05  818.0  721.0
# 9                       0.99                     0.05  809.0  773.0
# 10                      0.99                     0.05  853.0  718.0
# 11                      0.99                     0.05  810.0  743.0
# 12                      0.99                     0.05  823.0  762.0
# 13                      0.99                     0.05  833.0  744.0
# 14                      0.99                     0.05  816.0  769.0
# 15                      0.99                     0.05  791.0  776.0
# 16                      0.99                     0.05  794.0  758.0
# 17                      0.99                     0.05  812.0  753.0
# 18                      0.99                     0.05  817.0  786.0
# 19                      0.99                     0.05  851.0  734.0
# 20                      0.99                     0.05  840.0  734.0
# 21                      0.99                     0.05  825.0  773.0
# 22                      0.99                     0.05  828.0  753.0
# 23                      0.99                     0.05  833.0  728.0
# 24                      0.99                     0.05  825.0  747.0

# %%
res_4.to_csv('KNN_TrainTestSize.csv')

# %%
#Como se relaciona k con el tamaño del training set

# %%
#Experimentamos variando el tamaño del train test y k
#KNN + PCA

import sys
from multiprocessing import Pool

def run_grid_in_parallel(grid, n_proc=18):
    """Run a grid on n_proc workers"""
    done, results = 0, []
    
    def call_back(out):
        nonlocal done
        nonlocal results
        results.append(out)
        done += 1
        print('\r', f'Point {done}/{len(grid)} done', end='         ')
        sys.stdout.flush()

    with Pool(n_proc) as pool:
        for point in grid:
            pool.apply_async(run, args=(EXEC_PATH, point, ), callback=call_back)
        pool.close()
        pool.join()
    return pd.DataFrame(results)

file_names = ['../data/train_test_sample_' + str(i) + '.csv' for i in range(1000,25001,2000)]
grid_ranges = {
    'dataset': file_names,
    'output_file': ['../../datos/out.csv'], # Todavia no hace nada
    'mode': [1],
    'k': [1, 2, 3, 5, 7, 9, 10, 15, 20],
    'alpha': [50],
    'threshold_frecuency_low': [0.05],
    'threshold_frecuency_high': [0.99],
}
grid = list(build_grid(grid_ranges))
res_5 = run_grid_in_parallel(grid)
# Out:
#  Point 117/117 done

# %%
res_5
# Out:
#      Accuracy                         Dataset File        F1  Precision  \
# 0      0.5940   ../data/train_test_sample_1000.csv  0.588569   0.569412
# 1      0.5940   ../data/train_test_sample_1000.csv  0.588569   0.569412
# 2      0.5940   ../data/train_test_sample_1000.csv  0.588569   0.569412
# 3      0.5940   ../data/train_test_sample_1000.csv  0.588569   0.569412
# 4      0.5940   ../data/train_test_sample_1000.csv  0.588569   0.569412
# 5      0.5940   ../data/train_test_sample_1000.csv  0.588569   0.569412
# 6      0.5940   ../data/train_test_sample_1000.csv  0.588569   0.569412
# 7      0.5940   ../data/train_test_sample_1000.csv  0.588569   0.569412
# 8      0.5940   ../data/train_test_sample_1000.csv  0.588569   0.569412
# 9      0.6204   ../data/train_test_sample_3000.csv  0.594964   0.546667
# 10     0.6204   ../data/train_test_sample_3000.csv  0.594964   0.546667
# 11     0.6204   ../data/train_test_sample_3000.csv  0.594964   0.546667
# 12     0.6204   ../data/train_test_sample_3000.csv  0.594964   0.546667
# 13     0.6204   ../data/train_test_sample_3000.csv  0.594964   0.546667
# 14     0.6204   ../data/train_test_sample_3000.csv  0.594964   0.546667
# 15     0.6204   ../data/train_test_sample_3000.csv  0.594964   0.546667
# 16     0.6204   ../data/train_test_sample_3000.csv  0.594964   0.546667
# 17     0.6204   ../data/train_test_sample_3000.csv  0.594964   0.546667
# 18     0.6136   ../data/train_test_sample_5000.csv  0.616362   0.608627
# 19     0.6136   ../data/train_test_sample_5000.csv  0.616362   0.608627
# 20     0.6136   ../data/train_test_sample_5000.csv  0.616362   0.608627
# 21     0.6136   ../data/train_test_sample_5000.csv  0.616362   0.608627
# 22     0.6136   ../data/train_test_sample_5000.csv  0.616362   0.608627
# 23     0.6136   ../data/train_test_sample_5000.csv  0.616362   0.608627
# 24     0.6136   ../data/train_test_sample_5000.csv  0.616362   0.608627
# 25     0.6136   ../data/train_test_sample_5000.csv  0.616362   0.608627
# 26     0.6136   ../data/train_test_sample_5000.csv  0.616362   0.608627
# 27     0.6152   ../data/train_test_sample_7000.csv  0.607667   0.584314
# 28     0.6152   ../data/train_test_sample_7000.csv  0.607667   0.584314
# 29     0.6152   ../data/train_test_sample_7000.csv  0.607667   0.584314
# ..        ...                                  ...       ...        ...
# 87     0.6432  ../data/train_test_sample_19000.csv  0.640323   0.622745
# 88     0.6432  ../data/train_test_sample_19000.csv  0.640323   0.622745
# 89     0.6432  ../data/train_test_sample_19000.csv  0.640323   0.622745
# 90     0.6456  ../data/train_test_sample_21000.csv  0.641296   0.621176
# 91     0.6456  ../data/train_test_sample_21000.csv  0.641296   0.621176
# 92     0.6456  ../data/train_test_sample_21000.csv  0.641296   0.621176
# 93     0.6456  ../data/train_test_sample_21000.csv  0.641296   0.621176
# 94     0.6456  ../data/train_test_sample_21000.csv  0.641296   0.621176
# 95     0.6456  ../data/train_test_sample_21000.csv  0.641296   0.621176
# 96     0.6456  ../data/train_test_sample_21000.csv  0.641296   0.621176
# 97     0.6456  ../data/train_test_sample_21000.csv  0.641296   0.621176
# 98     0.6456  ../data/train_test_sample_21000.csv  0.641296   0.621176
# 99     0.6472  ../data/train_test_sample_23000.csv  0.645498   0.629804
# 100    0.6472  ../data/train_test_sample_23000.csv  0.645498   0.629804
# 101    0.6472  ../data/train_test_sample_23000.csv  0.645498   0.629804
# 102    0.6472  ../data/train_test_sample_23000.csv  0.645498   0.629804
# 103    0.6472  ../data/train_test_sample_23000.csv  0.645498   0.629804
# 104    0.6472  ../data/train_test_sample_23000.csv  0.645498   0.629804
# 105    0.6472  ../data/train_test_sample_23000.csv  0.645498   0.629804
# 106    0.6472  ../data/train_test_sample_23000.csv  0.645498   0.629804
# 107    0.6472  ../data/train_test_sample_23000.csv  0.645498   0.629804
# 108    0.6432  ../data/train_test_sample_25000.csv  0.643485   0.631373
# 109    0.6432  ../data/train_test_sample_25000.csv  0.643485   0.631373
# 110    0.6432  ../data/train_test_sample_25000.csv  0.643485   0.631373
# 95                       0.99                     0.05  822.0  792.0
# 96                       0.99                     0.05  822.0  792.0
# 97                       0.99                     0.05  822.0  792.0
# 98                       0.99                     0.05  822.0  792.0
# 99                       0.99                     0.05  815.0  803.0
# 100                      0.99                     0.05  815.0  803.0
# 101                      0.99                     0.05  815.0  803.0
# 102                      0.99                     0.05  815.0  803.0
# 103                      0.99                     0.05  815.0  803.0
# 104                      0.99                     0.05  815.0  803.0
# 105                      0.99                     0.05  815.0  803.0
# 106                      0.99                     0.05  815.0  803.0
# 107                      0.99                     0.05  815.0  803.0
# 108                      0.99                     0.05  803.0  805.0
# 109                      0.99                     0.05  803.0  805.0
# 110                      0.99                     0.05  803.0  805.0
# 111                      0.99                     0.05  803.0  805.0
# 112                      0.99                     0.05  803.0  805.0
# 113                      0.99                     0.05  803.0  805.0
# 114                      0.99                     0.05  803.0  805.0
# 115                      0.99                     0.05  803.0  805.0
# 116                      0.99                     0.05  803.0  805.0
#
# [117 rows x 15 columns]

# %%
res_5.to_csv('KNN_PCA_TrainTestSize_and_K.csv')

# %%
#Experimentamos variando el tamaño del train test y k
#KNN

import sys
from multiprocessing import Pool

def run_grid_in_parallel(grid, n_proc=18):
    """Run a grid on n_proc workers"""
    done, results = 0, []
    
    def call_back(out):
        nonlocal done
        nonlocal results
        results.append(out)
        done += 1
        print('\r', f'Point {done}/{len(grid)} done', end='         ')
        sys.stdout.flush()

    with Pool(n_proc) as pool:
        for point in grid:
            pool.apply_async(run, args=(EXEC_PATH, point, ), callback=call_back)
        pool.close()
        pool.join()
    return pd.DataFrame(results)

file_names = ['../data/train_test_sample_' + str(i) + '.csv' for i in range(1000,25001,2000)]
grid_ranges = {
    'dataset': file_names,
    'output_file': ['../../datos/out.csv'], # Todavia no hace nada
    'mode': [0],
    'k': [1, 2, 3, 5, 7, 9, 10, 15, 20],
    'alpha': [0],
    'threshold_frecuency_low': [0.05],
    'threshold_frecuency_high': [0.99],
}
grid = list(build_grid(grid_ranges))
res_6 = run_grid_in_parallel(grid)
# Out:
#  Point 117/117 done

# %%
res_6
# Out:
#      Accuracy                         Dataset File        F1  Precision  \
# 0      0.6040   ../data/train_test_sample_1000.csv  0.594262   0.568627
# 1      0.6040   ../data/train_test_sample_1000.csv  0.594262   0.568627
# 2      0.6040   ../data/train_test_sample_1000.csv  0.594262   0.568627
# 3      0.6040   ../data/train_test_sample_1000.csv  0.594262   0.568627
# 4      0.6040   ../data/train_test_sample_1000.csv  0.594262   0.568627
# 5      0.6040   ../data/train_test_sample_1000.csv  0.594262   0.568627
# 6      0.6040   ../data/train_test_sample_1000.csv  0.594262   0.568627
# 7      0.6040   ../data/train_test_sample_1000.csv  0.594262   0.568627
# 8      0.6040   ../data/train_test_sample_1000.csv  0.594262   0.568627
# 9      0.6252   ../data/train_test_sample_3000.csv  0.552745   0.454118
# 10     0.6252   ../data/train_test_sample_3000.csv  0.552745   0.454118
# 11     0.6252   ../data/train_test_sample_3000.csv  0.552745   0.454118
# 12     0.6252   ../data/train_test_sample_3000.csv  0.552745   0.454118
# 13     0.6252   ../data/train_test_sample_3000.csv  0.552745   0.454118
# 14     0.6252   ../data/train_test_sample_3000.csv  0.552745   0.454118
# 15     0.6252   ../data/train_test_sample_3000.csv  0.552745   0.454118
# 16     0.6252   ../data/train_test_sample_3000.csv  0.552745   0.454118
# 17     0.6252   ../data/train_test_sample_3000.csv  0.552745   0.454118
# 18     0.6116   ../data/train_test_sample_5000.csv  0.620851   0.623529
# 19     0.6116   ../data/train_test_sample_5000.csv  0.620851   0.623529
# 20     0.6116   ../data/train_test_sample_5000.csv  0.620851   0.623529
# 21     0.6116   ../data/train_test_sample_5000.csv  0.620851   0.623529
# 22     0.6116   ../data/train_test_sample_5000.csv  0.620851   0.623529
# 23     0.6116   ../data/train_test_sample_5000.csv  0.620851   0.623529
# 24     0.6116   ../data/train_test_sample_5000.csv  0.620851   0.623529
# 25     0.6116   ../data/train_test_sample_5000.csv  0.620851   0.623529
# 26     0.6116   ../data/train_test_sample_5000.csv  0.620851   0.623529
# 27     0.6196   ../data/train_test_sample_7000.csv  0.596863   0.552157
# 28     0.6196   ../data/train_test_sample_7000.csv  0.596863   0.552157
# 29     0.6196   ../data/train_test_sample_7000.csv  0.596863   0.552157
# ..        ...                                  ...       ...        ...
# 87     0.6412  ../data/train_test_sample_19000.csv  0.636695   0.616471
# 88     0.6412  ../data/train_test_sample_19000.csv  0.636695   0.616471
# 89     0.6412  ../data/train_test_sample_19000.csv  0.636695   0.616471
# 90     0.6296  ../data/train_test_sample_21000.csv  0.613200   0.575686
# 91     0.6296  ../data/train_test_sample_21000.csv  0.613200   0.575686
# 92     0.6296  ../data/train_test_sample_21000.csv  0.613200   0.575686
# 93     0.6296  ../data/train_test_sample_21000.csv  0.613200   0.575686
# 94     0.6296  ../data/train_test_sample_21000.csv  0.613200   0.575686
# 95     0.6296  ../data/train_test_sample_21000.csv  0.613200   0.575686
# 96     0.6296  ../data/train_test_sample_21000.csv  0.613200   0.575686
# 97     0.6296  ../data/train_test_sample_21000.csv  0.613200   0.575686
# 98     0.6296  ../data/train_test_sample_21000.csv  0.613200   0.575686
# 99     0.6324  ../data/train_test_sample_23000.csv  0.621031   0.590588
# 100    0.6324  ../data/train_test_sample_23000.csv  0.621031   0.590588
# 101    0.6324  ../data/train_test_sample_23000.csv  0.621031   0.590588
# 102    0.6324  ../data/train_test_sample_23000.csv  0.621031   0.590588
# 103    0.6324  ../data/train_test_sample_23000.csv  0.621031   0.590588
# 104    0.6324  ../data/train_test_sample_23000.csv  0.621031   0.590588
# 105    0.6324  ../data/train_test_sample_23000.csv  0.621031   0.590588
# 106    0.6324  ../data/train_test_sample_23000.csv  0.621031   0.590588
# 107    0.6324  ../data/train_test_sample_23000.csv  0.621031   0.590588
# 108    0.6288  ../data/train_test_sample_25000.csv  0.616846   0.585882
# 109    0.6288  ../data/train_test_sample_25000.csv  0.616846   0.585882
# 110    0.6288  ../data/train_test_sample_25000.csv  0.616846   0.585882
# 111    0.6288  ../data/train_test_sample_25000.csv  0.616846   0.585882
# 112    0.6288  ../data/train_test_sample_25000.csv  0.616846   0.585882
# 113    0.6288  ../data/train_test_sample_25000.csv  0.616846   0.585882
# 114    0.6288  ../data/train_test_sample_25000.csv  0.616846   0.585882
# 115    0.6288  ../data/train_test_sample_25000.csv  0.616846   0.585882
# 116    0.6288  ../data/train_test_sample_25000.csv  0.616846   0.585882
#
#        Recall       Time  alpha     fn     fp     k  mode  \
# 0    0.622318    5.28457    0.0  550.0  440.0   7.0   0.0
# 1    0.622318    5.28718    0.0  550.0  440.0   9.0   0.0
# 2    0.622318    5.31222    0.0  550.0  440.0  15.0   0.0
# 3    0.622318    5.32196    0.0  550.0  440.0   1.0   0.0
# 4    0.622318    5.31951    0.0  550.0  440.0  20.0   0.0
# 5    0.622318    5.31848    0.0  550.0  440.0   5.0   0.0
# 6    0.622318    5.32747    0.0  550.0  440.0   2.0   0.0
# 7    0.622318    5.36180    0.0  550.0  440.0  10.0   0.0
# 8    0.622318    5.36856    0.0  550.0  440.0   3.0   0.0
